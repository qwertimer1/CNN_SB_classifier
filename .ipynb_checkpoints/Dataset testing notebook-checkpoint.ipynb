# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ab4a0d3a28c8> in <module>()
# ----> 1 import torch
#       2 from torch.utils.data import Dataset
#       3
#       4 from PIL import Image
#       5 import os
#
# ModuleNotFoundError: No module named 'torch'

# %%
result = create_image_lists(data_dir, 20, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-cee18fa9c3ec> in <module>()
# ----> 1 result = create_image_lists(data_dir, 20, 10)
#
# TypeError: create_image_lists() takes 1 positional argument but 3 were given

# %%
len(result['outcrops']['training'])
# Out:
# 2470

# %%
import torch
from torch.utils.data import Dataset

from PIL import Image
import os
import glob
import re
import hashlib



class image_dataset(Dataset):
    def __init__(self, data_dir, 
                 label_filename,
                 testing_percentage,
                 validation_percentage, exp_phase = "training", transform=None):
        sub_dirs = []
        self.data_dir = data_dir
        self.sub_dirs = sub_dirs
        self.transform = transform
        self.testing_percentage = testing_percentage
        self.validation_percentage = validation_percentage
        self.exp_phase = exp_phase
        # reading img file from file
        self.result = self.create_image_lists()
        
        self.images, self.labels = self.convert_for_pytorch()
        
        
    
    def __getitem__(self, index):
        
        img = Image.open(os.path.join(self.data_dir, self.images[index]))
        
        
        img = img.convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        label = torch.from_numpy(self.label[index])
        return img, label
        
        

    def as_bytes(self, bytes_or_text, encoding='utf-8'):
        import six as _six

        """Converts either bytes or unicode to `bytes`, using utf-8 encoding for text.
        Args:
        bytes_or_text: A `bytes`, `str`, or `unicode` object.
        encoding: A string indicating the charset for encoding unicode.
        Returns:
        A `bytes` object.
        Raises:
        TypeError: If `bytes_or_text` is not a binary or unicode string.
        """
        if isinstance(bytes_or_text, _six.text_type):
            return bytes_or_text.encode(encoding)
        elif isinstance(bytes_or_text, bytes):
            return bytes_or_text
        else:
            raise TypeError('Expected binary or unicode string, got {}'.format(bytes_or_text,))

    def __len__(self):
        return len(self.results)
                           
    def convert_for_pytorch(self):
        
        self.images = []
        base_name = []
        is_root_dir = True
        for sub_dir in self.sub_dirs:
            if is_root_dir:
                is_root_dir = False
                continue
            base_name = os.path.basename(sub_dir)
            base_name = re.sub(r'[^a-z0-9]+', ' ', base_name.lower())
            
            vals = self.result[base_name][self.exp_phase]
            
            
            self.images.append(vals)
            self.labels = self.sub_dirs
        return self.images, self.labels
                         
            
        
       
    def create_image_lists(self):
        MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 -1

        
                             
        if not os.path.exists(self.data_dir):
            print("error")
            return None
        result = {}
        self.sub_dirs = [x[0] for x in os.walk(self.data_dir)]
        print(self.sub_dirs)
        is_root_dir = True
        for sub_dir in self.sub_dirs:
            if is_root_dir:
                is_root_dir = False
                continue
            extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
            file_list = []
            dir_name = os.path.basename(sub_dir)
            if dir_name == self.data_dir:
                continue
            for extension in extensions:
                file_glob = os.path.join(self.data_dir, dir_name, '*' + extension)
                file_list.extend(glob.glob(file_glob))
            if not file_list:
                print("No files found")
                continue
            if len(file_list) < 20:
                print("folder has less than 20 images, this may cause issues")
            if len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
                print("folder has too many images")
            self.label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
            self.training_images = []
            self.testing_images = []
            self.validation_images = []
            for file_name in file_list:
                base_name = os.path.basename(file_name)
                hash_name = re.sub(r'_nohash_.*$', '', file_name)
                hash_name_hashed = hashlib.sha1(self.as_bytes(hash_name)).hexdigest()
                percentage_hash = ((int(hash_name_hashed, 16) %
                                    (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                                   (100.0 / MAX_NUM_IMAGES_PER_CLASS))
                if percentage_hash < self.validation_percentage:
                    self.validation_images.append(base_name)
                elif percentage_hash < (self.testing_percentage + self.validation_percentage):
                    self.testing_images.append(base_name)
                else:
                    self.training_images.append(base_name)
                result[self.label_name] = {
                    'dir': dir_name,
                    'training': self.training_images,
                    'testing': self.testing_images,
                    'validation': self.validation_images,
                }
        return result

# %%
data_dir = 'D:\datasets\Seabed Images'
label_filename = 'D:\datasets\Seabed Images\labels.txt'

# %%
img_ds = image_dataset(data_dir, 
                       label_filename,
                       testing_percentage = 20,
                       validation_percentage = 10,
                       exp_phase = "training", 
                       transform = None )
# Out:
# ['D:\\datasets\\Seabed Images', 'D:\\datasets\\Seabed Images\\RIPPLES', 'D:\\datasets\\Seabed Images\\OUTCROPS', 'D:\\datasets\\Seabed Images\\MEGA', 'D:\\datasets\\Seabed Images\\POCKS', 'D:\\datasets\\Seabed Images\\ROCK', 'D:\\datasets\\Seabed Images\\SEA_GRASS', 'D:\\datasets\\Seabed Images\\DRAGS', 'D:\\datasets\\Seabed Images\\BLACKS', 'D:\\datasets\\Seabed Images\\FLATS', 'D:\\datasets\\Seabed Images\\SANDS', 'D:\\datasets\\Seabed Images\\ROUGHS']

# %%
img_ds.images
# Out:
# [['REMUS150_RHS_1.jpg',
#   'REMUS394_LHS_2.jpg',
#   'REMUS045_RHS_2.jpg',
#   'REMUS020_LHS_3.jpg',
#   'REMUS221_RHS_4.JPG',
#   '2008_081127PS_ADCP_REMUS_M8.JPG',
#   'REMUS090_RHS_2.jpg',
#   'REMUS045_RHS_4.JPG',
#   'REMUS015_LHS_2.JPG',
#   'REMUS071_RHS_3.jpg',
#   'REMUS143_RHS_4.jpg',
#   'REMUS046_LHS_2.JPG',
#   'REMUS133_LHS_4.JPG',
#   'REMUS040_LHS_3.jpg',
#   'REMUS069_RHS_2.JPG',
#   'REMUS086_RHS_2.jpg',
#   'REMUS093_LHS_3.jpg',
#   'REMUS203_LHS_1.jpg',
#   'REMUS101_LHS_2.jpg',
#   'REMUS233_LHS_1.JPG',
#   'REMUS401_LHS_1.JPG',
#   'REMUS138_RHS_1.jpg',
#   'REMUS064_LHS_2.jpg',
#   'REMUS071_RHS_1.jpg',
#   'REMUS034_RHS_4.JPG',
#   'REMUS119_RHS_3.jpg',
#   'REMUS232_LHS_4.JPG',
#   '2012_121203JB_ATR_REMUS_MS2.JPG',
#   'REMUS051_LHS_2.JPG',
#   'REMUS015_LHS_3.jpg',
#   'REMUS148_LHS_4.jpg',
#   'X34.JPG',
#   'REMUS023_LHS_3.jpg',
#   'REMUS032_LHS_4.JPG',
#   'REMUS107_RHS_4.jpg',
#   'REMUS066_LHS_3.jpg',
#   'REMUS087_LHS_4.jpg',
#   'REMUS032_LHS_1.jpg',
#   'REMUS104_RHS_3.jpg',
#   'REMUS128_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R05.JPG',
#   '2013_130717BB_ROUTE_SURVEY_.JPG',
#   'REMUS100_RHS_3.jpg',
#   'REMUS030_RHS_2.jpg',
#   'REMUS055_RHS_3.jpg',
#   'REMUS077_RHS_2.jpg',
#   'REMUS097_RHS_1.jpg',
#   'REMUS098_LHS_4.jpg',
#   'REMUS103_LHS_1.jpg',
#   '2010_100809JB_RPDE_WEEK3_R5.JPG',
#   'REMUS041_RHS_1.JPG',
#   'REMUS122_LHS_1.jpg',
#   'REMUS088_LHS_3.jpg',
#   'REMUS099_LHS_3.jpg',
#   'REMUS145_RHS_1.jpg',
#   'REMUS039_RHS_1.jpg',
#   'REMUS062_LHS_2.JPG',
#   'REMUS219_RHS_1.JPG',
#   'REMUS059_LHS_1.jpg',
#   'REMUS061_RHS_2.JPG',
#   'REMUS098_RHS_1.JPG',
#   'REMUS183_LHS_3.jpg',
#   '2008_081127PS_ADCP_REMUS_M1.JPG',
#   'REMUS099_RHS_3.JPG',
#   'REMUS074_LHS_4.jpg',
#   'REMUS062_RHS_4.jpg',
#   'REMUS072_LHS_4.jpg',
#   'REMUS089_RHS_2.jpg',
#   'REMUS030_LHS_4.jpg',
#   'REMUS184_LHS_2.jpg',
#   'REMUS098_LHS_3.JPG',
#   'REMUS005_LHS_3.jpg',
#   'REMUS084_LHS_2.jpg',
#   'REMUS050_LHS_3.JPG',
#   'X29.JPG',
#   'REMUS382_RHS_4.JPG',
#   'REMUS094_LHS_3.jpg',
#   'REMUS209_RHS_3.jpg',
#   'REMUS117_RHS_2.jpg',
#   'REMUS146_RHS_3.jpg',
#   'REMUS057_LHS_2.jpg',
#   'REMUS028_LHS_3.jpg',
#   'REMUS089_LHS_2.jpg',
#   'REMUS014_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R13.JPG',
#   'REMUS065_LHS_1.JPG',
#   'REMUS219_LHS_1.JPG',
#   'REMUS109_RHS_2.jpg',
#   'REMUS217_RHS_1.JPG',
#   'REMUS067_RHS_2.jpg',
#   'REMUS092_RHS_4.JPG',
#   'REMUS084_RHS_3.jpg',
#   'REMUS017_RHS_2.jpg',
#   'REMUS057_RHS_4.jpg',
#   'REMUS085_RHS_1.JPG',
#   'REMUS148_RHS_4.jpg',
#   'REMUS049_LHS_1.JPG',
#   'REMUS167_LHS_2.jpg',
#   'REMUS039_RHS_4.jpg',
#   'REMUS089_RHS_3.jpg',
#   'REMUS038_RHS_2.jpg',
#   'REMUS078_RHS_2.jpg',
#   'REMUS016_RHS_2.jpg',
#   'REMUS396_RHS_4.JPG',
#   '2008_081127PS_ADCP_REMUS_M4.JPG',
#   'REMUS220_LHS_2.JPG',
#   'REMUS068_LHS_4.jpg',
#   'REMUS034_RHS_3.JPG',
#   'REMUS049_LHS_2.JPG',
#   'REMUS101_LHS_4.jpg',
#   'REMUS044_LHS_1.jpg',
#   'REMUS101_LHS_1.JPG',
#   'REMUS077_LHS_1.jpg',
#   'REMUS068_RHS_3.jpg',
#   'REMUS069_LHS_1.JPG',
#   'REMUS042_LHS_4.jpg',
#   'REMUS050_LHS_2.JPG',
#   'REMUS051_LHS_4.jpg',
#   'REMUS100_LHS_4.JPG',
#   'REMUS121_LHS_3.jpg',
#   'REMUS212_RHS_2.jpg',
#   'REMUS205_RHS_2.jpg',
#   'REMUS099_RHS_1.JPG',
#   'REMUS058_RHS_3.JPG',
#   'REMUS235_RHS_3.JPG',
#   'REMUS210_RHS_2.jpg',
#   'REMUS032_RHS_3.jpg',
#   'REMUS085_RHS_4.JPG',
#   'REMUS030_RHS_4.jpg',
#   'REMUS205_LHS_1.jpg',
#   'REMUS052_RHS_1.jpg',
#   'X23.JPG',
#   'REMUS014_LHS_1.jpg',
#   'REMUS098_RHS_2.jpg',
#   'REMUS085_RHS_2.JPG',
#   'REMUS014_LHS_3.jpg',
#   'REMUS070_LHS_4.JPG',
#   'REMUS089_LHS_3.JPG',
#   'REMUS026_LHS_3.jpg',
#   'REMUS011_RHS_4.jpg',
#   'REMUS056_RHS_4.JPG',
#   'REMUS100_RHS_2.jpg',
#   'REMUS063_LHS_2.JPG',
#   'REMUS248_RHS_3.JPG',
#   'REMUS235_RHS_1.JPG',
#   'REMUS044_RHS_4.JPG',
#   'REMUS038_RHS_3.jpg',
#   'REMUS048_RHS_1.jpg',
#   'REMUS218_LHS_1.JPG',
#   'REMUS107_RHS_2.jpg',
#   'REMUS216_LHS_4.jpg',
#   'REMUS062_LHS_3.jpg',
#   'REMUS070_RHS_2.JPG',
#   'REMUS199_LHS_4.jpg',
#   'REMUS119_RHS_2.jpg',
#   'REMUS032_LHS_2.jpg',
#   'REMUS098_RHS_3.jpg',
#   'REMUS081_RHS_1.jpg',
#   'REMUS051_RHS_1.jpg',
#   'REMUS086_LHS_4.JPG',
#   'REMUS148_LHS_1.jpg',
#   'REMUS129_LHS_4.jpg',
#   'REMUS103_RHS_1.jpg',
#   'REMUS220_RHS_1.JPG',
#   'REMUS018_LHS_3.jpg',
#   'REMUS132_LHS_3.jpg',
#   'REMUS065_RHS_3.jpg',
#   'REMUS392_LHS_1.JPG',
#   'REMUS052_RHS_3.jpg',
#   'REMUS057_RHS_1.JPG',
#   'REMUS108_LHS_1.jpg',
#   'REMUS050_RHS_2.jpg',
#   'REMUS076_LHS_4.jpg',
#   'REMUS123_LHS_4.jpg',
#   'REMUS086_RHS_3.jpg',
#   'REMUS153_RHS_3.jpg',
#   'REMUS060_RHS_4.jpg',
#   'REMUS032_RHS_2.jpg',
#   'REMUS057_LHS_4.jpg',
#   'REMUS166_RHS_2.jpg',
#   'REMUS033_RHS_1.jpg',
#   'REMUS078_RHS_4.jpg',
#   'REMUS232_LHS_2.JPG',
#   'REMUS062_LHS_1.jpg',
#   'REMUS120_LHS_3.jpg',
#   'REMUS067_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R11.JPG',
#   'REMUS077_RHS_3.jpg',
#   'REMUS029_RHS_1.jpg',
#   'REMUS097_LHS_2.jpg',
#   'REMUS055_LHS_1.JPG',
#   'REMUS379_RHS_3.JPG',
#   'REMUS236_RHS_1.JPG',
#   'REMUS115_LHS_1.jpg',
#   'REMUS047_LHS_3.jpg',
#   'REMUS078_RHS_3.jpg',
#   'REMUS070_RHS_3.JPG',
#   'REMUS169_LHS_3.jpg',
#   'REMUS009_LHS_3.jpg',
#   'REMUS098_RHS_4.jpg',
#   'REMUS036_LHS_3.jpg',
#   'REMUS236_RHS_2.JPG',
#   'REMUS197_LHS_2.jpg',
#   'REMUS073_RHS_4.jpg',
#   'REMUS072_RHS_4.jpg',
#   'REMUS007_LHS_2.jpg',
#   'REMUS113_LHS_4.jpg',
#   'REMUS068_RHS_1.jpg',
#   'REMUS060_RHS_2.JPG',
#   'REMUS045_LHS_4.JPG',
#   'REMUS075_RHS_4.jpg',
#   'REMUS053_RHS_3.jpg',
#   'REMUS051_RHS_3.jpg',
#   'REMUS011_RHS_1.jpg',
#   'REMUS094_LHS_2.jpg',
#   'REMUS213_RHS_3.jpg',
#   'REMUS381_LHS_1.JPG',
#   'REMUS094_RHS_3.jpg',
#   'REMUS236_RHS_3.JPG',
#   'REMUS013_RHS_1.JPG',
#   'REMUS056_RHS_1.JPG',
#   'REMUS126_RHS_2.jpg',
#   'REMUS125_LHS_3.jpg',
#   'REMUS081_RHS_3.jpg',
#   'REMUS401_RHS_2.JPG',
#   'REMUS126_LHS_1.jpg',
#   'REMUS201_LHS_4.jpg',
#   'REMUS017_RHS_3.jpg',
#   'REMUS098_LHS_2.JPG',
#   'REMUS048_LHS_1.jpg',
#   'REMUS058_LHS_2.jpg',
#   'REMUS049_LHS_3.JPG',
#   'REMUS101_LHS_3.JPG',
#   'REMUS054_RHS_1.JPG',
#   'REMUS141_LHS_1.jpg',
#   'REMUS222_RHS_1.JPG',
#   'REMUS086_RHS_1.jpg',
#   'REMUS040_RHS_3.jpg',
#   'REMUS057_RHS_2.jpg',
#   'REMUS199_RHS_2.jpg',
#   'REMUS038_LHS_1.jpg',
#   'REMUS041_LHS_2.JPG',
#   'REMUS033_RHS_4.jpg',
#   'REMUS100_LHS_1.jpg',
#   'REMUS113_RHS_2.jpg',
#   'REMUS053_RHS_4.jpg',
#   'REMUS380_LHS_1.JPG',
#   'REMUS222_RHS_2.JPG',
#   'REMUS044_LHS_3.JPG',
#   'REMUS108_LHS_4.jpg',
#   'REMUS130_LHS_1.JPG',
#   'X42.JPG',
#   'REMUS118_LHS_1.jpg',
#   'REMUS161_LHS_4.jpg',
#   'REMUS062_RHS_1.jpg',
#   'REMUS183_LHS_1.jpg',
#   'REMUS054_LHS_4.JPG',
#   'REMUS064_LHS_4.jpg',
#   'REMUS068_LHS_1.JPG',
#   'REMUS199_RHS_1.jpg',
#   'REMUS381_LHS_3.JPG',
#   'REMUS128_LHS_2.jpg',
#   'REMUS056_LHS_1.JPG',
#   'REMUS059_LHS_3.jpg',
#   'REMUS401_RHS_3.JPG',
#   'REMUS096_RHS_4.jpg',
#   'REMUS061_RHS_3.JPG',
#   'X22.JPG',
#   'REMUS096_LHS_2.JPG',
#   'REMUS221_LHS_2.JPG',
#   'REMUS089_LHS_4.jpg',
#   'REMUS085_LHS_3.jpg',
#   'REMUS078_LHS_4.jpg',
#   'REMUS079_RHS_4.jpg',
#   'REMUS106_RHS_3.jpg',
#   'REMUS092_LHS_4.JPG',
#   'REMUS127_LHS_2.jpg',
#   'REMUS079_LHS_4.jpg',
#   'REMUS104_RHS_4.jpg',
#   'REMUS123_RHS_1.jpg',
#   'REMUS094_LHS_4.jpg',
#   'REMUS019_LHS_1.jpg',
#   'REMUS112_LHS_1.jpg',
#   'REMUS067_LHS_2.jpg',
#   'REMUS044_RHS_2.jpg',
#   'REMUS382_LHS_2.JPG',
#   'REMUS398_LHS_2.JPG',
#   'REMUS011_LHS_3.jpg',
#   'REMUS218_LHS_2.JPG',
#   'REMUS097_RHS_4.JPG',
#   'REMUS226_LHS_1.JPG',
#   'REMUS088_LHS_2.jpg',
#   'REMUS054_RHS_2.JPG',
#   'REMUS244_LHS_4.JPG',
#   'REMUS066_LHS_1.jpg',
#   'REMUS049_RHS_2.jpg',
#   'REMUS063_RHS_4.jpg',
#   'REMUS025_LHS_3.jpg',
#   'REMUS023_LHS_1.jpg',
#   'REMUS025_RHS_3.jpg',
#   'REMUS040_RHS_4.JPG',
#   'REMUS092_LHS_3.JPG',
#   'REMUS107_LHS_2.jpg',
#   'REMUS210_RHS_3.jpg',
#   'REMUS049_RHS_1.jpg',
#   'REMUS233_LHS_4.JPG',
#   'REMUS133_RHS_3.jpg',
#   'REMUS075_LHS_1.jpg',
#   'REMUS097_RHS_2.JPG',
#   'REMUS245_LHS_4.JPG',
#   'REMUS053_RHS_1.jpg',
#   'REMUS064_RHS_2.jpg',
#   '2010_100809JB_RPDE_WEEK3_R2.JPG',
#   'REMUS232_RHS_2.JPG',
#   'REMUS032_LHS_3.jpg',
#   'REMUS036_LHS_2.JPG',
#   'REMUS073_LHS_1.jpg',
#   'REMUS008_LHS_1.jpg',
#   'REMUS015_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R02.JPG',
#   'REMUS397_LHS_2.JPG',
#   'REMUS009_LHS_2.jpg',
#   'REMUS036_RHS_2.jpg',
#   'REMUS141_LHS_3.jpg',
#   'REMUS101_RHS_4.jpg',
#   'REMUS085_LHS_1.jpg',
#   '2007_070903JB_NAVACC_REMUS0.JPG',
#   'REMUS065_LHS_2.JPG',
#   'REMUS026_RHS_2.JPG',
#   'REMUS038_LHS_2.jpg',
#   'REMUS059_LHS_4.JPG',
#   'REMUS013_LHS_2.jpg',
#   'REMUS043_LHS_2.JPG',
#   'REMUS090_RHS_4.jpg',
#   'REMUS102_RHS_1.jpg',
#   'REMUS068_RHS_4.jpg',
#   'REMUS069_LHS_4.JPG',
#   '2008_081127PS_ADCP_REMUS_M0.JPG',
#   'REMUS017_RHS_4.jpg',
#   'REMUS141_RHS_1.jpg',
#   'REMUS211_RHS_2.jpg',
#   'REMUS034_RHS_1.jpg',
#   'REMUS014_RHS_3.jpg',
#   'REMUS079_RHS_3.jpg',
#   'REMUS056_LHS_3.jpg',
#   'REMUS183_LHS_2.jpg',
#   'REMUS060_LHS_4.jpg',
#   'REMUS211_RHS_4.jpg',
#   '2010_100809JB_RPDE_WEEK3_R3.JPG',
#   'REMUS102_LHS_2.jpg',
#   'REMUS034_LHS_2.jpg',
#   'REMUS074_RHS_4.jpg',
#   'REMUS058_LHS_3.JPG',
#   'REMUS093_RHS_2.JPG',
#   'REMUS059_RHS_4.jpg',
#   'REMUS063_LHS_4.JPG',
#   'REMUS048_RHS_2.jpg',
#   'REMUS015_RHS_1.JPG',
#   'REMUS013_LHS_1.JPG',
#   'REMUS135_LHS_3.JPG',
#   'REMUS051_RHS_2.JPG',
#   'REMUS024_LHS_4.jpg',
#   'REMUS051_RHS_4.jpg',
#   'REMUS118_LHS_2.jpg',
#   'REMUS021_LHS_1.jpg',
#   'REMUS114_LHS_2.jpg',
#   'REMUS100_RHS_4.JPG',
#   'REMUS091_RHS_1.JPG',
#   'REMUS086_LHS_3.JPG',
#   'REMUS113_RHS_3.jpg',
#   'REMUS099_LHS_4.JPG',
#   'REMUS056_RHS_3.jpg',
#   'REMUS037_RHS_3.jpg',
#   'REMUS035_LHS_3.jpg',
#   'REMUS083_RHS_3.jpg',
#   'REMUS080_LHS_3.jpg',
#   '2014_141003PM_TTCP_2014_R04.JPG',
#   'REMUS398_RHS_2.JPG',
#   'REMUS028_RHS_3.jpg',
#   '2014_141003PM_TTCP_2014_R01.JPG',
#   'REMUS397_RHS_1.JPG',
#   'REMUS108_RHS_2.jpg',
#   'REMUS092_LHS_1.JPG',
#   'REMUS109_RHS_1.jpg',
#   'REMUS094_RHS_4.jpg',
#   'REMUS088_LHS_1.jpg',
#   'REMUS234_RHS_1.JPG',
#   'REMUS129_LHS_3.jpg',
#   'REMUS200_RHS_3.jpg',
#   'REMUS235_LHS_4.JPG',
#   'REMUS086_RHS_4.jpg',
#   'REMUS055_RHS_1.jpg',
#   'REMUS065_LHS_3.JPG',
#   'REMUS070_RHS_4.jpg',
#   'REMUS128_LHS_3.JPG',
#   'REMUS395_RHS_2.JPG',
#   'REMUS090_RHS_1.jpg',
#   'REMUS122_LHS_3.jpg',
#   'REMUS035_RHS_4.jpg',
#   'REMUS109_LHS_4.jpg',
#   'REMUS197_RHS_1.jpg',
#   'REMUS034_LHS_3.JPG',
#   'REMUS203_RHS_3.jpg',
#   'REMUS029_RHS_4.jpg',
#   'REMUS082_RHS_1.jpg',
#   'REMUS087_RHS_3.jpg',
#   'REMUS070_LHS_2.JPG',
#   'REMUS093_LHS_1.JPG',
#   'REMUS243_RHS_3.JPG',
#   '2008_080903JB_MINEREC_REMU1.JPG',
#   'REMUS036_LHS_1.jpg',
#   'REMUS124_LHS_1.jpg',
#   'REMUS042_RHS_2.JPG',
#   'REMUS010_RHS_1.jpg',
#   'REMUS037_LHS_4.jpg',
#   'REMUS044_RHS_3.JPG',
#   'REMUS211_LHS_4.jpg',
#   'REMUS056_LHS_2.JPG',
#   'REMUS398_LHS_3.JPG',
#   'REMUS107_RHS_3.jpg',
#   '2014_141003PM_TTCP_2014_R10.JPG',
#   'REMUS063_LHS_1.jpg',
#   'REMUS087_LHS_1.JPG',
#   'REMUS380_RHS_3.JPG',
#   'REMUS042_RHS_3.JPG',
#   'REMUS099_LHS_2.jpg',
#   'REMUS091_LHS_1.JPG',
#   'REMUS221_RHS_3.JPG',
#   'REMUS036_RHS_4.jpg',
#   'REMUS165_LHS_2.jpg',
#   'REMUS049_RHS_4.jpg',
#   'REMUS079_LHS_2.jpg',
#   'REMUS023_LHS_4.jpg',
#   'REMUS400_RHS_1.JPG',
#   'REMUS047_RHS_1.jpg',
#   'REMUS235_LHS_1.JPG',
#   '2012_121203JB_ATR_REMUS_MS5.JPG',
#   'REMUS013_LHS_4.jpg',
#   'REMUS111_RHS_2.jpg',
#   'REMUS076_RHS_4.jpg',
#   'REMUS132_LHS_2.JPG',
#   'REMUS031_RHS_1.jpg',
#   'REMUS134_LHS_4.JPG',
#   'REMUS204_RHS_2.jpg',
#   'REMUS046_RHS_3.jpg',
#   'REMUS035_LHS_4.jpg',
#   'REMUS089_LHS_1.jpg',
#   'REMUS028_LHS_1.jpg',
#   'REMUS018_RHS_4.jpg',
#   'REMUS117_RHS_1.jpg',
#   'REMUS036_RHS_1.jpg',
#   'REMUS108_RHS_4.jpg',
#   'REMUS109_LHS_3.jpg',
#   'REMUS104_RHS_2.jpg',
#   'REMUS114_RHS_3.jpg',
#   'REMUS083_LHS_3.jpg',
#   'REMUS040_RHS_2.JPG',
#   'REMUS209_RHS_2.jpg',
#   'REMUS181_RHS_3.jpg',
#   'REMUS023_RHS_1.jpg',
#   'REMUS084_LHS_4.jpg',
#   'REMUS028_RHS_1.jpg',
#   'REMUS028_LHS_2.jpg',
#   'REMUS095_LHS_3.jpg',
#   'REMUS029_RHS_3.jpg',
#   'REMUS091_RHS_2.jpg',
#   'REMUS398_RHS_3.JPG',
#   'REMUS083_LHS_4.jpg',
#   'REMUS125_LHS_1.jpg',
#   'REMUS045_LHS_3.JPG',
#   'REMUS073_RHS_2.jpg',
#   'REMUS041_RHS_2.jpg',
#   'REMUS116_RHS_4.jpg',
#   'REMUS398_RHS_4.JPG',
#   'REMUS157_RHS_3.jpg',
#   'REMUS090_LHS_4.JPG',
#   'REMUS144_RHS_3.jpg',
#   'REMUS096_RHS_1.jpg',
#   'REMUS074_RHS_2.jpg',
#   'REMUS005_RHS_2.jpg',
#   'X41.JPG',
#   'REMUS040_LHS_2.JPG',
#   'REMUS234_RHS_2.JPG',
#   'REMUS213_LHS_4.JPG',
#   'REMUS121_RHS_3.jpg',
#   'REMUS061_LHS_1.jpg',
#   'REMUS086_LHS_2.jpg',
#   'REMUS008_LHS_2.jpg',
#   'REMUS088_LHS_4.jpg',
#   'REMUS015_RHS_3.jpg',
#   'REMUS047_RHS_2.jpg',
#   'REMUS082_LHS_4.jpg',
#   'REMUS084_LHS_1.jpg',
#   'REMUS233_RHS_2.JPG',
#   'REMUS395_RHS_4.JPG',
#   'REMUS206_LHS_3.jpg',
#   'REMUS106_RHS_4.jpg',
#   'REMUS213_RHS_4.jpg',
#   'REMUS247_RHS_1.JPG',
#   'REMUS019_LHS_2.jpg',
#   'REMUS045_RHS_3.jpg',
#   'REMUS202_LHS_4.jpg',
#   'REMUS017_RHS_1.jpg',
#   'REMUS222_LHS_2.JPG',
#   'REMUS100_LHS_3.JPG',
#   'REMUS043_RHS_3.jpg',
#   'REMUS069_RHS_4.JPG',
#   'REMUS079_LHS_3.jpg',
#   'REMUS400_LHS_1.JPG',
#   'REMUS009_LHS_4.jpg',
#   '2010_100809JB_RPDE_WEEK3_R7.JPG',
#   'REMUS220_LHS_3.JPG',
#   'REMUS037_RHS_2.jpg',
#   'REMUS106_LHS_4.jpg',
#   'REMUS203_RHS_2.jpg',
#   'REMUS114_LHS_1.jpg',
#   'REMUS038_LHS_4.jpg',
#   'REMUS031_LHS_2.JPG',
#   'REMUS085_LHS_4.jpg',
#   '2008_081127PS_ADCP_REMUS_M7.JPG',
#   'REMUS383_RHS_4.JPG',
#   'REMUS218_RHS_3.JPG',
#   'REMUS146_LHS_1.jpg',
#   'REMUS398_RHS_1.JPG',
#   'REMUS219_LHS_4.JPG',
#   'REMUS087_RHS_4.jpg',
#   'REMUS219_RHS_3.JPG',
#   '2009_091019TAS_DUGONG_REMU2.JPG',
#   'REMUS063_RHS_2.JPG',
#   'REMUS154_RHS_3.jpg',
#   'REMUS093_RHS_3.jpg',
#   'REMUS061_LHS_4.jpg',
#   'REMUS096_RHS_2.jpg',
#   'REMUS082_LHS_3.jpg',
#   'REMUS043_RHS_4.jpg',
#   'REMUS208_LHS_2.jpg',
#   'REMUS202_RHS_3.jpg',
#   'REMUS071_LHS_3.jpg',
#   'REMUS077_LHS_3.jpg',
#   'REMUS011_LHS_4.jpg',
#   'REMUS061_RHS_1.jpg',
#   '2010_100809JB_RPDE_WEEK3_R6.JPG',
#   'REMUS078_RHS_1.jpg',
#   'REMUS382_RHS_1.JPG',
#   'REMUS005_LHS_4.jpg',
#   'REMUS027_RHS_1.jpg',
#   'REMUS217_RHS_2.JPG',
#   'REMUS032_RHS_4.jpg',
#   'REMUS072_RHS_2.jpg',
#   'REMUS042_RHS_4.JPG',
#   'REMUS026_LHS_4.jpg',
#   'REMUS119_LHS_4.jpg',
#   'REMUS024_LHS_2.jpg',
#   'REMUS112_LHS_2.jpg',
#   'REMUS027_LHS_1.jpg',
#   'REMUS083_RHS_4.jpg',
#   'REMUS105_RHS_3.jpg',
#   'REMUS196_LHS_1.jpg',
#   'REMUS219_LHS_3.JPG',
#   'REMUS065_RHS_1.jpg',
#   'REMUS092_RHS_1.JPG',
#   'REMUS380_RHS_1.JPG',
#   'REMUS081_RHS_2.jpg',
#   'REMUS038_LHS_3.jpg',
#   'REMUS016_LHS_4.jpg',
#   'REMUS046_LHS_1.JPG',
#   'REMUS395_RHS_1.JPG',
#   'REMUS048_RHS_4.jpg',
#   'REMUS142_LHS_4.jpg',
#   'REMUS129_LHS_1.JPG',
#   'REMUS022_RHS_2.jpg',
#   'REMUS077_RHS_1.jpg',
#   'REMUS031_LHS_4.JPG',
#   'REMUS027_RHS_4.JPG',
#   'REMUS040_LHS_4.jpg',
#   'REMUS395_LHS_1.JPG',
#   'REMUS047_LHS_2.jpg',
#   'REMUS067_RHS_4.jpg',
#   'REMUS129_RHS_1.jpg',
#   'REMUS062_RHS_3.JPG',
#   'REMUS042_LHS_3.jpg',
#   'REMUS202_RHS_2.jpg',
#   'REMUS095_RHS_1.jpg',
#   'REMUS008_LHS_4.jpg',
#   'REMUS030_RHS_3.jpg',
#   'REMUS244_RHS_2.JPG',
#   '2013_130530BB_ROUTE_SURVEY1.JPG',
#   'REMUS103_RHS_3.jpg',
#   'REMUS140_LHS_1.JPG',
#   'REMUS034_RHS_2.jpg',
#   'REMUS043_LHS_4.jpg',
#   'REMUS201_RHS_1.jpg',
#   'REMUS031_RHS_3.jpg',
#   'REMUS100_LHS_2.jpg',
#   'REMUS222_LHS_3.JPG',
#   'REMUS233_RHS_3.JPG',
#   'REMUS089_RHS_4.jpg',
#   'REMUS029_LHS_1.jpg',
#   'REMUS243_RHS_1.JPG',
#   'REMUS084_RHS_1.jpg',
#   'REMUS075_LHS_2.jpg',
#   'REMUS030_LHS_1.JPG',
#   'REMUS203_RHS_4.jpg',
#   'REMUS245_RHS_4.JPG',
#   'REMUS236_LHS_2.JPG',
#   '2008_081127PS_ADCP_REMUS_M6.JPG',
#   'REMUS072_RHS_3.jpg',
#   'X26.JPG',
#   'REMUS050_RHS_4.jpg',
#   'REMUS083_RHS_2.jpg',
#   'REMUS054_RHS_4.jpg',
#   'REMUS197_LHS_4.jpg',
#   'REMUS234_LHS_3.JPG',
#   'REMUS126_RHS_4.jpg',
#   'REMUS097_LHS_1.jpg',
#   'REMUS395_LHS_2.JPG',
#   'REMUS222_LHS_4.JPG',
#   'REMUS104_LHS_1.jpg',
#   'REMUS066_LHS_2.JPG',
#   'REMUS098_LHS_1.JPG',
#   'REMUS030_LHS_3.jpg',
#   'REMUS122_LHS_2.jpg',
#   'REMUS101_RHS_1.JPG',
#   'REMUS197_LHS_1.jpg',
#   'REMUS092_RHS_3.JPG',
#   'REMUS033_LHS_3.jpg',
#   'REMUS008_LHS_3.JPG',
#   'REMUS026_RHS_3.JPG',
#   'REMUS028_RHS_4.jpg',
#   'REMUS040_RHS_1.JPG',
#   'REMUS037_LHS_1.jpg',
#   'REMUS035_RHS_3.JPG',
#   'REMUS232_LHS_3.JPG',
#   'REMUS082_RHS_4.jpg',
#   'REMUS118_RHS_3.jpg',
#   'REMUS074_RHS_1.jpg',
#   'REMUS145_RHS_2.jpg',
#   'REMUS093_LHS_2.jpg',
#   'REMUS061_LHS_2.jpg',
#   'REMUS090_LHS_2.jpg',
#   'REMUS089_RHS_1.jpg',
#   'REMUS062_RHS_2.jpg',
#   'REMUS131_LHS_1.JPG',
#   'REMUS127_LHS_4.jpg',
#   'REMUS060_RHS_1.jpg',
#   'X18.JPG',
#   '2008_080903JB_MINEREC_REMU0.JPG',
#   'REMUS082_RHS_3.jpg',
#   'REMUS132_RHS_1.jpg',
#   'REMUS202_LHS_1.jpg',
#   'REMUS218_RHS_1.JPG',
#   'REMUS046_LHS_4.jpg',
#   'REMUS081_RHS_4.jpg',
#   'REMUS127_LHS_3.jpg',
#   'REMUS112_LHS_3.jpg',
#   'REMUS102_RHS_3.jpg',
#   'REMUS110_LHS_4.jpg',
#   'REMUS041_LHS_1.JPG',
#   'REMUS146_RHS_2.jpg',
#   'REMUS087_LHS_2.JPG',
#   '2012_121203JB_ATR_REMUS_MS4.JPG',
#   'REMUS074_LHS_1.jpg',
#   'REMUS119_LHS_1.jpg',
#   'REMUS029_RHS_2.jpg',
#   'REMUS041_RHS_4.jpg',
#   'REMUS220_RHS_4.JPG',
#   'X21.JPG',
#   'REMUS025_LHS_2.jpg',
#   'REMUS067_LHS_1.jpg',
#   'REMUS232_LHS_1.JPG',
#   'REMUS401_LHS_2.JPG',
#   'REMUS068_RHS_2.JPG',
#   'REMUS136_RHS_1.jpg',
#   'REMUS064_RHS_1.jpg',
#   'REMUS031_LHS_3.JPG',
#   'REMUS111_LHS_2.jpg',
#   'REMUS075_RHS_2.jpg',
#   'REMUS094_RHS_1.jpg',
#   'REMUS088_RHS_2.jpg',
#   'REMUS223_LHS_4.JPG',
#   'REMUS111_LHS_1.jpg',
#   'REMUS143_RHS_2.jpg',
#   'REMUS079_RHS_2.jpg',
#   'REMUS083_LHS_2.jpg',
#   'REMUS042_LHS_1.jpg',
#   'REMUS235_RHS_4.JPG',
#   'REMUS008_RHS_1.jpg',
#   'REMUS074_LHS_2.jpg',
#   'REMUS026_RHS_4.jpg',
#   'REMUS221_RHS_1.JPG',
#   'REMUS113_LHS_1.jpg',
#   'REMUS093_RHS_1.jpg',
#   'REMUS234_LHS_1.JPG',
#   'REMUS027_LHS_4.jpg',
#   'REMUS116_RHS_2.jpg',
#   'X19.JPG',
#   'REMUS064_RHS_4.jpg',
#   'REMUS075_LHS_3.jpg',
#   'REMUS104_LHS_2.jpg',
#   'REMUS133_LHS_3.jpg',
#   'REMUS210_RHS_1.jpg',
#   'REMUS058_RHS_1.JPG',
#   'REMUS399_RHS_3.JPG',
#   'REMUS039_RHS_3.jpg',
#   'REMUS024_RHS_4.jpg',
#   'REMUS126_LHS_3.jpg',
#   '2012_121203JB_ATR_REMUS_MS1.JPG',
#   'REMUS142_LHS_3.JPG',
#   'REMUS048_RHS_3.jpg',
#   '2014_141003PM_TTCP_2014_R07.JPG',
#   'REMUS104_RHS_1.jpg',
#   'REMUS226_LHS_2.JPG',
#   'REMUS381_LHS_4.JPG',
#   'REMUS067_LHS_3.jpg',
#   'REMUS233_LHS_2.JPG',
#   'REMUS105_LHS_4.jpg',
#   '2009_091019TAS_DUGONG_REMU0.JPG',
#   'REMUS110_LHS_2.jpg',
#   'REMUS383_LHS_4.JPG',
#   'REMUS161_LHS_2.jpg',
#   'REMUS121_RHS_4.jpg',
#   'REMUS016_RHS_3.jpg',
#   'REMUS044_LHS_2.jpg',
#   'REMUS133_RHS_4.jpg',
#   'REMUS010_RHS_3.jpg',
#   'REMUS399_RHS_2.JPG',
#   'REMUS234_LHS_4.JPG',
#   'REMUS210_LHS_1.jpg',
#   'REMUS143_LHS_2.jpg',
#   '2009_091019TAS_DUGONG_REMU1.JPG',
#   'REMUS095_RHS_4.JPG',
#   'REMUS146_LHS_3.jpg',
#   'REMUS043_LHS_1.jpg',
#   'REMUS211_RHS_1.jpg',
#   'REMUS071_LHS_2.JPG',
#   'REMUS226_LHS_3.JPG',
#   'REMUS204_RHS_4.jpg',
#   'REMUS140_RHS_1.jpg',
#   'REMUS046_RHS_2.jpg',
#   'REMUS047_RHS_3.jpg',
#   'REMUS011_LHS_1.jpg',
#   'REMUS153_LHS_1.jpg',
#   'REMUS219_RHS_4.JPG',
#   'REMUS236_RHS_4.JPG',
#   'REMUS095_RHS_3.jpg',
#   'REMUS184_LHS_3.jpg',
#   'REMUS035_LHS_2.jpg',
#   'REMUS118_RHS_2.jpg',
#   '2008_081127PS_ADCP_REMUS_M3.JPG',
#   'REMUS200_LHS_1.jpg',
#   'REMUS101_RHS_3.JPG',
#   'REMUS142_LHS_1.jpg',
#   'REMUS067_RHS_1.jpg',
#   'REMUS073_LHS_4.jpg',
#   'REMUS233_RHS_4.JPG',
#   'REMUS232_RHS_4.JPG',
#   'REMUS151_RHS_4.jpg',
#   'REMUS075_LHS_4.jpg',
#   'REMUS020_RHS_3.jpg',
#   'X25.JPG',
#   'REMUS105_LHS_3.jpg',
#   'REMUS093_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R03.JPG',
#   'REMUS223_RHS_3.JPG',
#   'REMUS218_LHS_3.JPG',
#   'REMUS053_LHS_2.jpg',
#   'REMUS116_LHS_4.jpg',
#   'REMUS111_RHS_1.jpg',
#   'REMUS074_LHS_3.jpg',
#   'REMUS080_RHS_4.jpg',
#   'REMUS151_RHS_3.jpg',
#   'REMUS039_RHS_2.jpg',
#   'REMUS163_RHS_1.jpg',
#   'REMUS213_LHS_3.jpg',
#   'REMUS209_LHS_3.jpg',
#   'REMUS395_RHS_3.JPG',
#   'REMUS023_RHS_3.jpg',
#   'REMUS069_LHS_3.JPG',
#   'REMUS116_LHS_3.jpg',
#   'REMUS081_LHS_1.jpg',
#   '2010_100809JB_RPDE_WEEK3_R1.JPG',
#   'REMUS064_LHS_1.jpg',
#   'REMUS024_LHS_1.jpg',
#   'REMUS007_LHS_1.JPG',
#   '2013_130530BB_ROUTE_SURVEY0.JPG',
#   'REMUS125_LHS_2.jpg',
#   'REMUS198_LHS_1.jpg',
#   'REMUS185_LHS_4.jpg',
#   'REMUS112_LHS_4.jpg',
#   'REMUS128_RHS_2.jpg',
#   'REMUS024_LHS_3.jpg',
#   'REMUS037_RHS_1.jpg',
#   'REMUS248_RHS_4.JPG',
#   'REMUS381_RHS_3.JPG',
#   'REMUS167_LHS_1.jpg',
#   'REMUS218_LHS_4.JPG',
#   'REMUS212_LHS_2.jpg',
#   'REMUS382_LHS_1.JPG',
#   'REMUS123_LHS_2.jpg',
#   'REMUS025_RHS_2.jpg',
#   'REMUS400_RHS_3.JPG',
#   'REMUS010_LHS_4.jpg',
#   'REMUS080_RHS_2.jpg',
#   'REMUS127_LHS_1.jpg',
#   'REMUS082_LHS_1.jpg',
#   'REMUS221_LHS_3.JPG',
#   'REMUS121_RHS_1.jpg',
#   'REMUS234_LHS_2.JPG',
#   'REMUS016_RHS_1.jpg',
#   'REMUS153_LHS_3.jpg',
#   'REMUS236_LHS_3.JPG',
#   'REMUS046_RHS_1.JPG',
#   'REMUS102_LHS_1.jpg',
#   'REMUS107_LHS_3.jpg',
#   'REMUS212_RHS_3.jpg',
#   'REMUS087_RHS_2.jpg',
#   'REMUS027_RHS_2.jpg',
#   'REMUS037_LHS_3.jpg',
#   'REMUS073_LHS_3.jpg',
#   'REMUS212_LHS_1.jpg',
#   'REMUS095_LHS_4.jpg',
#   'REMUS235_RHS_2.JPG',
#   'REMUS025_LHS_1.jpg',
#   'REMUS129_RHS_2.jpg',
#   'REMUS211_LHS_3.jpg',
#   'REMUS020_LHS_1.jpg',
#   'REMUS070_LHS_3.jpg',
#   'REMUS016_RHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R12.JPG',
#   'REMUS033_LHS_1.jpg',
#   'REMUS199_LHS_3.jpg',
#   'REMUS120_RHS_2.jpg',
#   'REMUS152_RHS_3.jpg',
#   'REMUS075_RHS_3.jpg',
#   'REMUS109_LHS_2.jpg',
#   'REMUS017_LHS_4.jpg',
#   'REMUS244_LHS_1.JPG',
#   'REMUS162_LHS_2.jpg',
#   'REMUS023_RHS_2.jpg',
#   '2014_141003PM_TTCP_2014_R06.JPG',
#   'REMUS064_LHS_3.jpg',
#   'REMUS078_LHS_3.jpg',
#   'REMUS072_LHS_1.jpg',
#   'REMUS237_LHS_1.JPG',
#   'REMUS012_RHS_4.jpg',
#   'REMUS082_LHS_2.jpg',
#   'REMUS038_RHS_4.jpg',
#   'REMUS197_RHS_3.jpg',
#   'X36.JPG',
#   'REMUS150_RHS_1.jpg',
#   'REMUS394_LHS_2.jpg',
#   'REMUS045_RHS_2.jpg',
#   'REMUS020_LHS_3.jpg',
#   'REMUS221_RHS_4.JPG',
#   '2008_081127PS_ADCP_REMUS_M8.JPG',
#   'REMUS090_RHS_2.jpg',
#   'REMUS045_RHS_4.JPG',
#   'REMUS015_LHS_2.JPG',
#   'REMUS071_RHS_3.jpg',
#   'REMUS143_RHS_4.jpg',
#   'REMUS046_LHS_2.JPG',
#   'REMUS133_LHS_4.JPG',
#   'REMUS040_LHS_3.jpg',
#   'REMUS069_RHS_2.JPG',
#   'REMUS086_RHS_2.jpg',
#   'REMUS093_LHS_3.jpg',
#   'REMUS203_LHS_1.jpg',
#   'REMUS101_LHS_2.jpg',
#   'REMUS233_LHS_1.JPG',
#   'REMUS401_LHS_1.JPG',
#   'REMUS138_RHS_1.jpg',
#   'REMUS064_LHS_2.jpg',
#   'REMUS071_RHS_1.jpg',
#   'REMUS034_RHS_4.JPG',
#   'REMUS119_RHS_3.jpg',
#   'REMUS232_LHS_4.JPG',
#   '2012_121203JB_ATR_REMUS_MS2.JPG',
#   'REMUS051_LHS_2.JPG',
#   'REMUS015_LHS_3.jpg',
#   'REMUS148_LHS_4.jpg',
#   'X34.JPG',
#   'REMUS023_LHS_3.jpg',
#   'REMUS032_LHS_4.JPG',
#   'REMUS107_RHS_4.jpg',
#   'REMUS066_LHS_3.jpg',
#   'REMUS087_LHS_4.jpg',
#   'REMUS032_LHS_1.jpg',
#   'REMUS104_RHS_3.jpg',
#   'REMUS128_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R05.JPG',
#   '2013_130717BB_ROUTE_SURVEY_.JPG',
#   'REMUS100_RHS_3.jpg',
#   'REMUS030_RHS_2.jpg',
#   'REMUS055_RHS_3.jpg',
#   'REMUS077_RHS_2.jpg',
#   'REMUS097_RHS_1.jpg',
#   'REMUS098_LHS_4.jpg',
#   'REMUS103_LHS_1.jpg',
#   '2010_100809JB_RPDE_WEEK3_R5.JPG',
#   'REMUS041_RHS_1.JPG',
#   'REMUS122_LHS_1.jpg',
#   'REMUS088_LHS_3.jpg',
#   'REMUS099_LHS_3.jpg',
#   'REMUS145_RHS_1.jpg',
#   'REMUS039_RHS_1.jpg',
#   'REMUS062_LHS_2.JPG',
#   'REMUS219_RHS_1.JPG',
#   'REMUS059_LHS_1.jpg',
#   'REMUS061_RHS_2.JPG',
#   'REMUS098_RHS_1.JPG',
#   'REMUS183_LHS_3.jpg',
#   '2008_081127PS_ADCP_REMUS_M1.JPG',
#   'REMUS099_RHS_3.JPG',
#   'REMUS074_LHS_4.jpg',
#   'REMUS062_RHS_4.jpg',
#   'REMUS072_LHS_4.jpg',
#   'REMUS089_RHS_2.jpg',
#   'REMUS030_LHS_4.jpg',
#   'REMUS184_LHS_2.jpg',
#   'REMUS098_LHS_3.JPG',
#   'REMUS005_LHS_3.jpg',
#   'REMUS084_LHS_2.jpg',
#   'REMUS050_LHS_3.JPG',
#   'X29.JPG',
#   'REMUS382_RHS_4.JPG',
#   'REMUS094_LHS_3.jpg',
#   'REMUS209_RHS_3.jpg',
#   'REMUS117_RHS_2.jpg',
#   'REMUS146_RHS_3.jpg',
#   'REMUS057_LHS_2.jpg',
#   'REMUS028_LHS_3.jpg',
#   'REMUS089_LHS_2.jpg',
#   'REMUS014_LHS_4.jpg',
#   '2014_141003PM_TTCP_2014_R13.JPG',
#   'REMUS065_LHS_1.JPG',
#   'REMUS219_LHS_1.JPG',
#   'REMUS109_RHS_2.jpg',
#   'REMUS217_RHS_1.JPG',
#   'REMUS067_RHS_2.jpg',
#   'REMUS092_RHS_4.JPG',
#   'REMUS084_RHS_3.jpg',
#   'REMUS017_RHS_2.jpg',
#   'REMUS057_RHS_4.jpg',
#   'REMUS085_RHS_1.JPG',
#   'REMUS148_RHS_4.jpg',
#   'REMUS049_LHS_1.JPG',
#   'REMUS167_LHS_2.jpg',
#   'REMUS039_RHS_4.jpg',
#   'REMUS089_RHS_3.jpg',
#   'REMUS038_RHS_2.jpg',
#   'REMUS078_RHS_2.jpg',
#   'REMUS016_RHS_2.jpg',
#   'REMUS396_RHS_4.JPG',
#   '2008_081127PS_ADCP_REMUS_M4.JPG',
#   'REMUS220_LHS_2.JPG',
#   'REMUS068_LHS_4.jpg',
#   'REMUS034_RHS_3.JPG',
#   'REMUS049_LHS_2.JPG',
#   'REMUS101_LHS_4.jpg',
#   'REMUS044_LHS_1.jpg',
#   'REMUS101_LHS_1.JPG',
#   'REMUS077_LHS_1.jpg',
#   'REMUS068_RHS_3.jpg',
#   'REMUS069_LHS_1.JPG',
#   'REMUS042_LHS_4.jpg',
#   'REMUS050_LHS_2.JPG',
#   'REMUS051_LHS_4.jpg',
#   'REMUS100_LHS_4.JPG',
#   'REMUS121_LHS_3.jpg',
#   'REMUS212_RHS_2.jpg',
#   'REMUS205_RHS_2.jpg',
#   'REMUS099_RHS_1.JPG',
#   'REMUS058_RHS_3.JPG',
#   'REMUS235_RHS_3.JPG',
#   'REMUS210_RHS_2.jpg',
#   'REMUS032_RHS_3.jpg',
#   'REMUS085_RHS_4.JPG',
#   'REMUS030_RHS_4.jpg',
#   'REMUS205_LHS_1.jpg',
#   'REMUS052_RHS_1.jpg',
#   'X23.JPG',
#   'REMUS014_LHS_1.jpg',
#   'REMUS098_RHS_2.jpg',
#   'REMUS085_RHS_2.JPG',
#   'REMUS014_LHS_3.jpg',
#   'REMUS070_LHS_4.JPG',
#   'REMUS089_LHS_3.JPG',
#   'REMUS026_LHS_3.jpg',
#   'REMUS011_RHS_4.jpg',
#   'REMUS056_RHS_4.JPG',
#   'REMUS100_RHS_2.jpg',
#   'REMUS063_LHS_2.JPG',
#   'REMUS248_RHS_3.JPG',
#   'REMUS235_RHS_1.JPG',
#   'REMUS044_RHS_4.JPG',
#   'REMUS038_RHS_3.jpg',
#   'REMUS048_RHS_1.jpg',
#   'REMUS218_LHS_1.JPG',
#   'REMUS107_RHS_2.jpg',
#   'REMUS216_LHS_4.jpg',
#   ...],
#  ['REMUS260_RHS_2.jpg',
#   'REMUS452_RHS_3.JPG',
#   'REMUS131_RHS_4.jpg',
#   'REMUS431_RHS_3.JPG',
#   'REMUS539_LHS_4.jpg',
#   'REMUS256_LHS_3.jpg',
#   'REMUS468_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_023.JPG',
#   'REMUS311_RHS_4.jpg',
#   'REMUS456_LHS_4.jpg',
#   'REMUS278_LHS_2.JPG',
#   'REMUS281_LHS_1.jpg',
#   'REMUS336_LHS_2.JPG',
#   'REMUS290_LHS_2.jpg',
#   'REMUS311_LHS_4.jpg',
#   'REMUS370_RHS_1.JPG',
#   'REMUS398_RHS_2.jpg',
#   'REMUS452_LHS_1.JPG',
#   'REMUS489_RHS_2.jpg',
#   'REMUS532_RHS_3.jpg',
#   'REMUS286_LHS_4.JPG',
#   'REMUS293_LHS_2.jpg',
#   'REMUS333_RHS_3.JPG',
#   'REMUS314_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_189.JPG',
#   'REMUS352_RHS_1.JPG',
#   'REMUS294_RHS_4.JPG',
#   'REMUS328_RHS_4.jpg',
#   'REMUS293_LHS_3.jpg',
#   'REMUS363_RHS_1.jpg',
#   'REMUS520_LHS_3.jpg',
#   'REMUS315_LHS_1.JPG',
#   'REMUS029_RHS_2.JPG',
#   'REMUS501_LHS_3.JPG',
#   'REMUS331_LHS_1.jpg',
#   'REMUS502_LHS_3.JPG',
#   'REMUS295_RHS_3.JPG',
#   'REMUS311_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_180.JPG',
#   'REMUS324_RHS_2.jpg',
#   'REMUS360_RHS_3.JPG',
#   'REMUS534_LHS_2.jpg',
#   'REMUS528_LHS_1.jpg',
#   'REMUS289_LHS_4.JPG',
#   'REMUS296_RHS_4.jpg',
#   'REMUS490_LHS_2.jpg',
#   'REMUS310_LHS_4.JPG',
#   'REMUS268_LHS_1.jpg',
#   'REMUS292_LHS_1.jpg',
#   'REMUS350_RHS_2.JPG',
#   '2007_071211NQ_WARMWATER_209.JPG',
#   'REMUS066_LHS_3.jpg',
#   'REMUS489_RHS_4.JPG',
#   'REMUS267_RHS_1.jpg',
#   'REMUS307_LHS_1.JPG',
#   'REMUS326_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_232.JPG',
#   'REMUS343_LHS_1.JPG',
#   'REMUS349_LHS_2.JPG',
#   '2007_071211NQ_WARMWATER_183.JPG',
#   'REMUS307_LHS_4.JPG',
#   'REMUS324_RHS_1.jpg',
#   'REMUS491_LHS_3.jpg',
#   'REMUS299_LHS_3.JPG',
#   'REMUS511_RHS_1.JPG',
#   'REMUS312_RHS_1.jpg',
#   'REMUS295_RHS_2.jpg',
#   'REMUS109_LHS_1.jpg',
#   'REMUS354_LHS_4.JPG',
#   'REMUS354_RHS_1.JPG',
#   'REMUS300_LHS_2.JPG',
#   'REMUS253_LHS_2.jpg',
#   'REMUS298_RHS_4.JPG',
#   'REMUS118_LHS_4.jpg',
#   'REMUS285_LHS_4.jpg',
#   'REMUS279_LHS_3.JPG',
#   'REMUS339_LHS_1.JPG',
#   'REMUS277_RHS_1.JPG',
#   'REMUS351_LHS_2.JPG',
#   'REMUS486_LHS_3.jpg',
#   'REMUS430_LHS_2.jpg',
#   'REMUS514_RHS_4.jpg',
#   'REMUS367_LHS_1.JPG',
#   'REMUS441_RHS_2.jpg',
#   'REMUS336_RHS_2.jpg',
#   'REMUS313_LHS_2.jpg',
#   'REMUS360_LHS_1.JPG',
#   'REMUS349_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_066.JPG',
#   'REMUS074_LHS_4.jpg',
#   'REMUS358_LHS_3.JPG',
#   'REMUS062_RHS_4.jpg',
#   'REMUS426_RHS_2.jpg',
#   'REMUS380_RHS_1.jpg',
#   'REMUS441_LHS_3.jpg',
#   'O04.JPG',
#   'REMUS307_RHS_2.JPG',
#   'REMUS493_RHS_2.jpg',
#   'REMUS342_LHS_4.jpg',
#   'REMUS363_RHS_2.jpg',
#   'REMUS329_LHS_2.JPG',
#   'REMUS309_LHS_2.JPG',
#   'REMUS115_RHS_2.jpg',
#   'REMUS287_LHS_2.JPG',
#   '2007_071211NQ_WARMWATER_120.JPG',
#   'REMUS334_LHS_2.JPG',
#   'REMUS308_RHS_3.jpg',
#   'REMUS298_LHS_1.jpg',
#   'REMUS272_RHS_2.jpg',
#   'REMUS339_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_105.JPG',
#   'REMUS260_LHS_4.jpg',
#   'REMUS263_RHS_1.jpg',
#   'REMUS267_RHS_3.jpg',
#   'REMUS235_LHS_2.jpg',
#   'REMUS418_LHS_3.jpg',
#   'REMUS505_LHS_1.JPG',
#   'REMUS278_RHS_1.jpg',
#   '2013_130919_GAVIA_TASMANIA4.JPG',
#   'REMUS393_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_096.JPG',
#   'REMUS335_RHS_3.jpg',
#   'REMUS258_RHS_4.jpg',
#   'REMUS441_LHS_2.JPG',
#   'REMUS506_RHS_4.jpg',
#   'REMUS295_LHS_1.jpg',
#   'REMUS352_LHS_4.JPG',
#   'REMUS336_RHS_1.jpg',
#   'REMUS313_LHS_3.jpg',
#   'REMUS483_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_103.JPG',
#   'REMUS491_RHS_2.JPG',
#   'REMUS282_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_210.JPG',
#   'REMUS286_RHS_2.jpg',
#   'REMUS395_RHS_1.jpg',
#   'REMUS236_LHS_2.jpg',
#   'REMUS292_RHS_4.jpg',
#   'REMUS283_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_166.JPG',
#   'REMUS294_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_126.JPG',
#   'REMUS312_LHS_4.jpg',
#   'REMUS336_LHS_1.JPG',
#   'REMUS346_RHS_4.JPG',
#   'REMUS084_RHS_3.jpg',
#   'REMUS252_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_231.JPG',
#   '2007_071211NQ_WARMWATER_219.JPG',
#   'REMUS363_LHS_2.jpg',
#   'REMUS289_RHS_3.JPG',
#   'REMUS283_LHS_4.jpg',
#   'REMUS320_RHS_4.JPG',
#   'REMUS354_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_147.JPG',
#   'REMUS358_RHS_2.jpg',
#   'REMUS375_RHS_4.JPG',
#   'REMUS357_LHS_4.JPG',
#   'REMUS420_RHS_4.jpg',
#   'REMUS277_LHS_2.JPG',
#   'REMUS493_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_119.JPG',
#   'REMUS351_LHS_4.JPG',
#   'REMUS314_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_152.JPG',
#   'REMUS462_LHS_3.jpg',
#   'REMUS456_LHS_2.jpg',
#   'REMUS296_RHS_1.JPG',
#   'REMUS281_RHS_2.JPG',
#   'REMUS350_LHS_1.jpg',
#   'REMUS325_LHS_3.jpg',
#   'REMUS274_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_241.JPG',
#   'REMUS267_RHS_4.jpg',
#   'REMUS309_RHS_2.jpg',
#   'REMUS322_RHS_2.JPG',
#   'REMUS301_LHS_3.jpg',
#   'REMUS256_RHS_4.jpg',
#   'REMUS347_RHS_3.jpg',
#   'REMUS482_LHS_1.jpg',
#   'REMUS274_RHS_1.jpg',
#   'REMUS318_LHS_4.JPG',
#   'REMUS397_RHS_4.jpg',
#   'REMUS337_LHS_1.JPG',
#   'REMUS285_LHS_1.JPG',
#   'O05.JPG',
#   'REMUS385_RHS_2.jpg',
#   'REMUS355_RHS_4.jpg',
#   'REMUS288_LHS_4.jpg',
#   'REMUS466_RHS_1.jpg',
#   'REMUS391_RHS_3.jpg',
#   'REMUS304_LHS_4.JPG',
#   'REMUS051_LHS_4.jpg',
#   'REMUS276_LHS_2.jpg',
#   'REMUS358_LHS_4.jpg',
#   'REMUS279_RHS_4.jpg',
#   'REMUS407_RHS_3.jpg',
#   'REMUS504_RHS_2.JPG',
#   'REMUS309_RHS_1.jpg',
#   'REMUS260_RHS_1.jpg',
#   'REMUS525_RHS_2.jpg',
#   'REMUS510_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_171.JPG',
#   'REMUS328_RHS_2.JPG',
#   'REMUS360_RHS_4.jpg',
#   'REMUS285_RHS_3.jpg',
#   'REMUS117_LHS_1.jpg',
#   'REMUS319_LHS_2.JPG',
#   'REMUS505_LHS_2.jpg',
#   'REMUS420_RHS_3.JPG',
#   'REMUS434_LHS_2.jpg',
#   'REMUS327_RHS_4.JPG',
#   'O07.JPG',
#   'REMUS259_RHS_3.jpg',
#   'REMUS519_RHS_1.jpg',
#   'REMUS332_LHS_2.JPG',
#   'REMUS322_RHS_1.JPG',
#   'REMUS328_LHS_3.jpg',
#   'REMUS329_LHS_1.JPG',
#   'REMUS315_RHS_3.jpg',
#   'REMUS435_RHS_1.JPG',
#   'REMUS357_RHS_4.jpg',
#   'REMUS351_LHS_1.jpg',
#   'REMUS331_RHS_4.jpg',
#   'REMUS081_LHS_2.jpg',
#   'REMUS508_LHS_2.JPG',
#   'REMUS314_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_097.JPG',
#   'REMUS331_LHS_3.JPG',
#   'REMUS515_RHS_1.JPG',
#   'REMUS363_RHS_3.JPG',
#   'REMUS486_RHS_4.jpg',
#   'REMUS504_LHS_2.jpg',
#   'REMUS254_RHS_1.jpg',
#   'REMUS327_RHS_3.JPG',
#   'REMUS469_RHS_3.jpg',
#   'REMUS048_RHS_1.jpg',
#   'REMUS152_LHS_3.jpg',
#   'REMUS315_LHS_2.jpg',
#   'REMUS288_RHS_4.JPG',
#   'REMUS223_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_095.JPG',
#   'REMUS341_LHS_2.jpg',
#   'REMUS335_RHS_4.JPG',
#   '2007_071211NQ_WARMWATER_242.JPG',
#   'REMUS475_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_112.JPG',
#   'REMUS351_RHS_4.jpg',
#   'REMUS350_LHS_2.jpg',
#   'REMUS405_LHS_4.jpg',
#   'REMUS018_LHS_3.jpg',
#   'REMUS313_RHS_4.jpg',
#   'REMUS353_LHS_3.jpg',
#   'REMUS132_LHS_3.jpg',
#   'REMUS279_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_122.JPG',
#   'REMUS344_LHS_2.JPG',
#   'REMUS299_RHS_3.jpg',
#   'REMUS230_LHS_4.jpg',
#   'REMUS349_LHS_3.jpg',
#   'REMUS323_RHS_3.JPG',
#   'REMUS438_RHS_3.jpg',
#   'REMUS257_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_185.JPG',
#   'REMUS531_RHS_1.jpg',
#   'REMUS352_LHS_1.JPG',
#   'REMUS348_RHS_1.jpg',
#   'REMUS108_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_191.JPG',
#   'REMUS377_LHS_1.jpg',
#   'REMUS281_LHS_3.JPG',
#   'REMUS336_RHS_4.JPG',
#   'REMUS310_LHS_1.JPG',
#   'REMUS405_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_230.JPG',
#   'REMUS393_LHS_3.jpg',
#   'REMUS354_LHS_1.jpg',
#   'REMUS294_RHS_2.jpg',
#   'REMUS384_RHS_2.jpg',
#   'REMUS298_LHS_4.JPG',
#   'REMUS342_LHS_1.jpg',
#   'REMUS521_LHS_1.jpg',
#   'REMUS264_RHS_4.jpg',
#   'REMUS343_LHS_4.jpg',
#   'REMUS296_LHS_1.JPG',
#   'REMUS256_RHS_2.jpg',
#   'REMUS518_RHS_2.jpg',
#   'REMUS297_RHS_3.JPG',
#   'REMUS438_LHS_4.JPG',
#   'REMUS322_LHS_4.JPG',
#   'REMUS120_LHS_3.jpg',
#   'REMUS509_RHS_3.jpg',
#   'REMUS259_LHS_1.jpg',
#   'REMUS291_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_117.JPG',
#   'REMUS332_LHS_3.jpg',
#   'REMUS444_LHS_2.jpg',
#   'REMUS124_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_221.JPG',
#   'REMUS380_LHS_1.jpg',
#   'REMUS341_LHS_4.jpg',
#   'REMUS344_LHS_4.jpg',
#   'REMUS279_RHS_1.jpg',
#   'REMUS318_RHS_4.JPG',
#   'REMUS338_RHS_1.jpg',
#   'REMUS499_RHS_2.jpg',
#   'REMUS521_LHS_3.jpg',
#   'REMUS483_RHS_3.JPG',
#   'REMUS305_LHS_4.jpg',
#   'REMUS332_RHS_4.JPG',
#   '2007_071211NQ_WARMWATER_094.JPG',
#   'REMUS265_LHS_4.jpg',
#   'REMUS147_RHS_1.jpg',
#   'REMUS009_LHS_3.jpg',
#   'REMUS278_LHS_4.JPG',
#   'REMUS290_RHS_1.jpg',
#   'REMUS259_LHS_2.jpg',
#   'REMUS461_LHS_4.jpg',
#   'REMUS521_LHS_2.jpg',
#   'REMUS478_LHS_3.JPG',
#   'REMUS280_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_151.JPG',
#   'REMUS429_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_054.JPG',
#   'REMUS317_RHS_4.JPG',
#   'REMUS332_RHS_1.jpg',
#   'REMUS343_LHS_2.JPG',
#   'REMUS276_RHS_4.jpg',
#   'REMUS535_RHS_4.jpg',
#   'REMUS310_RHS_1.jpg',
#   'REMUS404_LHS_3.JPG',
#   'REMUS492_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_072.JPG',
#   'REMUS300_RHS_1.JPG',
#   'REMUS353_RHS_4.JPG',
#   'REMUS308_RHS_2.jpg',
#   'REMUS303_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_060.JPG',
#   'REMUS371_RHS_4.jpg',
#   'REMUS332_LHS_1.jpg',
#   'REMUS339_RHS_4.jpg',
#   'REMUS331_RHS_3.jpg',
#   'REMUS255_RHS_2.jpg',
#   'REMUS282_RHS_1.jpg',
#   'REMUS357_RHS_2.jpg',
#   'REMUS335_RHS_1.JPG',
#   'REMUS344_LHS_3.JPG',
#   'REMUS499_LHS_3.jpg',
#   'REMUS275_RHS_1.jpg',
#   'REMUS329_RHS_4.JPG',
#   'REMUS328_LHS_1.jpg',
#   'REMUS317_RHS_2.JPG',
#   'REMUS529_RHS_2.jpg',
#   'REMUS344_LHS_1.jpg',
#   'REMUS307_RHS_1.JPG',
#   'REMUS279_LHS_2.jpg',
#   'REMUS366_LHS_2.JPG',
#   'REMUS222_LHS_1.jpg',
#   'REMUS361_RHS_1.JPG',
#   'REMUS317_RHS_3.jpg',
#   'REMUS268_RHS_1.jpg',
#   'REMUS324_RHS_3.JPG',
#   'REMUS334_LHS_3.JPG',
#   'REMUS326_LHS_1.JPG',
#   'REMUS259_RHS_1.jpg',
#   'REMUS315_RHS_4.JPG',
#   'REMUS445_RHS_3.jpg',
#   'REMUS388_RHS_2.JPG',
#   'REMUS397_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_079.JPG',
#   'REMUS419_RHS_2.jpg',
#   'REMUS389_LHS_1.JPG',
#   'REMUS048_LHS_1.jpg',
#   'REMUS308_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_108.JPG',
#   'REMUS361_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_016.JPG',
#   'REMUS282_LHS_3.JPG',
#   'REMUS359_LHS_2.JPG',
#   'REMUS528_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_035.JPG',
#   'REMUS339_LHS_2.jpg',
#   'REMUS308_LHS_1.jpg',
#   'REMUS418_LHS_2.jpg',
#   'REMUS321_LHS_2.jpg',
#   'REMUS517_LHS_1.JPG',
#   'REMUS277_RHS_2.JPG',
#   'REMUS355_LHS_4.jpg',
#   'O01.JPG',
#   '2007_071211NQ_WARMWATER_145.JPG',
#   'REMUS304_LHS_1.JPG',
#   'REMUS297_RHS_2.JPG',
#   'REMUS354_RHS_4.JPG',
#   'REMUS118_LHS_3.jpg',
#   'REMUS401_RHS_4.jpg',
#   '2013_130618BB_MGDST_BANTRY_.JPG',
#   'REMUS436_RHS_3.jpg',
#   'REMUS334_LHS_1.JPG',
#   'REMUS453_RHS_2.jpg',
#   'REMUS282_LHS_1.JPG',
#   'REMUS459_RHS_3.JPG',
#   'REMUS320_LHS_2.jpg',
#   'REMUS288_RHS_2.JPG',
#   'REMUS311_LHS_3.JPG',
#   'REMUS381_RHS_2.jpg',
#   'REMUS292_LHS_2.JPG',
#   '2007_071211NQ_WARMWATER_067.JPG',
#   '2007_071211NQ_WARMWATER_136.JPG',
#   'REMUS297_LHS_3.JPG',
#   'REMUS105_RHS_4.JPG',
#   'REMUS366_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_158.JPG',
#   'REMUS108_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_168.JPG',
#   'REMUS398_LHS_2.jpg',
#   'REMUS365_RHS_4.jpg',
#   'REMUS224_LHS_2.jpg',
#   'REMUS265_RHS_4.jpg',
#   'REMUS293_RHS_2.JPG',
#   'REMUS359_LHS_4.JPG',
#   'REMUS268_RHS_2.jpg',
#   'REMUS342_LHS_2.JPG',
#   'REMUS310_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_149.JPG',
#   'REMUS359_RHS_2.jpg',
#   'REMUS314_RHS_4.jpg',
#   'REMUS305_LHS_2.JPG',
#   'REMUS128_LHS_2.jpg',
#   'REMUS322_LHS_1.JPG',
#   'REMUS330_LHS_3.JPG',
#   'REMUS538_RHS_3.jpg',
#   'REMUS292_LHS_3.JPG',
#   'REMUS349_RHS_3.JPG',
#   'REMUS337_RHS_4.jpg',
#   'REMUS264_RHS_3.jpg',
#   'REMUS481_LHS_1.jpg',
#   'REMUS287_RHS_3.JPG',
#   'REMUS309_LHS_4.jpg',
#   'REMUS516_LHS_1.jpg',
#   'REMUS453_LHS_1.JPG',
#   'REMUS279_RHS_2.jpg',
#   'REMUS289_RHS_2.JPG',
#   'REMUS253_LHS_1.jpg',
#   'REMUS335_LHS_4.JPG',
#   'REMUS010_LHS_4.JPG',
#   'REMUS300_RHS_2.jpg',
#   'REMUS504_LHS_1.jpg',
#   'REMUS345_RHS_3.jpg',
#   'REMUS330_RHS_1.JPG',
#   'REMUS473_LHS_4.JPG',
#   'REMUS422_LHS_1.jpg',
#   '2013_130919_GAVIA_TASMANIA0.JPG',
#   'REMUS391_LHS_3.jpg',
#   'REMUS316_LHS_4.jpg',
#   'REMUS323_RHS_1.jpg',
#   'REMUS104_RHS_4.jpg',
#   'REMUS510_LHS_4.JPG',
#   'REMUS328_LHS_2.JPG',
#   '2007_071211NQ_WARMWATER_150.JPG',
#   '2007_071211NQ_WARMWATER_148.JPG',
#   'REMUS263_RHS_4.jpg',
#   'REMUS365_LHS_4.jpg',
#   'REMUS471_LHS_1.jpg',
#   'O02.JPG',
#   'REMUS460_RHS_1.jpg',
#   'REMUS176_LHS_2.jpg',
#   'REMUS352_LHS_2.JPG',
#   'REMUS422_RHS_3.jpg',
#   'REMUS464_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_244.JPG',
#   'REMUS333_RHS_1.JPG',
#   'REMUS305_RHS_4.jpg',
#   'REMUS346_LHS_2.JPG',
#   'REMUS258_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_229.JPG',
#   'REMUS286_RHS_3.JPG',
#   'REMUS504_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_121.JPG',
#   'REMUS224_LHS_1.jpg',
#   'REMUS378_RHS_2.jpg',
#   'REMUS403_LHS_1.jpg',
#   'REMUS328_RHS_1.jpg',
#   'REMUS277_LHS_1.JPG',
#   'REMUS345_LHS_1.JPG',
#   'REMUS101_LHS_3.jpg',
#   'REMUS358_RHS_3.jpg',
#   'REMUS066_RHS_2.jpg',
#   'REMUS297_LHS_2.jpg',
#   'REMUS298_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_013.JPG',
#   'REMUS414_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_203.JPG',
#   '2007_071211NQ_WARMWATER_002.JPG',
#   '2007_071211NQ_WARMWATER_194.JPG',
#   'REMUS104_RHS_1.JPG',
#   '2007_071211NQ_WARMWATER_224.JPG',
#   'REMUS521_RHS_4.jpg',
#   'REMUS448_LHS_2.JPG',
#   'REMUS378_LHS_2.jpg',
#   'REMUS399_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_138.JPG',
#   'REMUS295_RHS_1.jpg',
#   'REMUS427_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_175.JPG',
#   'REMUS357_LHS_1.JPG',
#   'REMUS304_LHS_2.JPG',
#   'REMUS422_RHS_2.jpg',
#   'REMUS309_LHS_3.JPG',
#   'REMUS459_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_204.JPG',
#   'REMUS292_RHS_1.jpg',
#   'REMUS341_LHS_3.JPG',
#   'REMUS288_RHS_1.JPG',
#   'REMUS253_RHS_4.jpg',
#   'REMUS326_RHS_2.jpg',
#   'REMUS269_RHS_4.jpg',
#   'REMUS281_RHS_3.JPG',
#   'REMUS290_LHS_3.JPG',
#   'REMUS330_RHS_3.JPG',
#   'REMUS277_LHS_4.JPG',
#   'REMUS036_RHS_2.jpg',
#   'REMUS348_RHS_4.jpg',
#   'REMUS337_RHS_1.jpg',
#   'REMUS327_LHS_3.jpg',
#   'REMUS340_LHS_3.jpg',
#   'REMUS470_LHS_3.jpg',
#   'REMUS505_LHS_4.jpg',
#   'REMUS141_LHS_2.jpg',
#   'REMUS306_RHS_4.JPG',
#   'REMUS462_LHS_2.jpg',
#   'REMUS522_RHS_2.jpg',
#   'REMUS409_LHS_3.jpg',
#   'REMUS357_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_163.JPG',
#   '2007_071211NQ_WARMWATER_052.JPG',
#   'REMUS389_RHS_1.jpg',
#   'REMUS457_LHS_1.JPG',
#   'REMUS304_RHS_1.JPG',
#   'REMUS447_LHS_1.jpg',
#   'REMUS528_RHS_2.jpg',
#   'REMUS068_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_085.JPG',
#   'REMUS355_RHS_2.JPG',
#   'REMUS321_LHS_4.JPG',
#   'REMUS475_LHS_1.jpg',
#   'REMUS296_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_173.JPG',
#   'REMUS029_LHS_3.jpg',
#   'REMUS306_LHS_3.jpg',
#   'REMUS512_RHS_4.jpg',
#   'REMUS305_RHS_2.JPG',
#   'REMUS361_LHS_1.JPG',
#   'REMUS437_RHS_2.JPG',
#   'REMUS296_LHS_3.JPG',
#   'REMUS275_RHS_3.jpg',
#   'REMUS535_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_077.JPG',
#   '2007_071211NQ_WARMWATER_154.JPG',
#   'REMUS464_LHS_2.jpg',
#   'REMUS346_RHS_1.jpg',
#   'REMUS473_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_005.JPG',
#   'REMUS527_RHS_3.jpg',
#   'REMUS365_RHS_1.JPG',
#   'REMUS293_RHS_3.JPG',
#   'REMUS467_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_034.JPG',
#   'REMUS327_LHS_4.jpg',
#   'REMUS444_RHS_1.jpg',
#   'REMUS293_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_192.JPG',
#   '2007_071211NQ_WARMWATER_076.JPG',
#   'REMUS487_LHS_1.JPG',
#   'REMUS340_LHS_2.JPG',
#   'REMUS353_RHS_1.jpg',
#   'REMUS493_LHS_2.JPG',
#   'REMUS186_LHS_1.jpg',
#   'REMUS253_LHS_4.jpg',
#   'REMUS355_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_129.JPG',
#   'REMUS404_LHS_1.jpg',
#   'REMUS493_RHS_3.jpg',
#   'REMUS388_RHS_3.JPG',
#   'REMUS333_RHS_2.jpg',
#   'REMUS345_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_128.JPG',
#   'REMUS295_RHS_4.jpg',
#   'REMUS526_RHS_4.jpg',
#   'REMUS425_RHS_3.jpg',
#   'REMUS288_LHS_2.jpg',
#   'REMUS118_LHS_2.jpg',
#   'REMUS375_RHS_3.jpg',
#   'REMUS142_LHS_2.jpg',
#   'REMUS473_LHS_2.JPG',
#   'REMUS256_LHS_4.jpg',
#   'REMUS451_RHS_4.JPG',
#   'REMUS314_LHS_1.jpg',
#   'REMUS346_RHS_3.jpg',
#   'REMUS342_LHS_3.jpg',
#   'REMUS478_RHS_1.JPG',
#   'REMUS284_RHS_4.JPG',
#   'REMUS360_RHS_1.JPG',
#   'REMUS312_RHS_4.JPG',
#   'REMUS276_LHS_1.jpg',
#   'REMUS355_RHS_3.jpg',
#   'REMUS321_RHS_4.jpg',
#   'REMUS511_RHS_4.JPG',
#   'REMUS393_LHS_4.JPG',
#   'REMUS329_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_186.JPG',
#   'REMUS270_RHS_3.jpg',
#   'REMUS317_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_205.JPG',
#   'REMUS257_RHS_3.jpg',
#   'REMUS428_RHS_3.jpg',
#   'REMUS348_LHS_1.JPG',
#   'REMUS526_LHS_2.jpg',
#   'REMUS488_RHS_2.jpg',
#   'REMUS319_LHS_1.jpg',
#   'REMUS393_RHS_1.JPG',
#   'REMUS374_LHS_1.jpg',
#   'REMUS532_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_026.JPG',
#   'REMUS274_LHS_3.jpg',
#   'REMUS447_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_011.JPG',
#   '2007_071211NQ_WARMWATER_008.JPG',
#   'REMUS311_RHS_1.JPG',
#   'REMUS399_LHS_2.jpg',
#   'REMUS343_RHS_2.jpg',
#   'REMUS335_LHS_1.JPG',
#   'REMUS530_LHS_4.jpg',
#   'REMUS260_RHS_3.jpg',
#   'REMUS456_RHS_4.jpg',
#   'O06.JPG',
#   'REMUS086_RHS_4.jpg',
#   'REMUS510_RHS_1.jpg',
#   'REMUS528_RHS_1.jpg',
#   'REMUS055_RHS_1.jpg',
#   '2007_071211NQ_WARMWATER_089.JPG',
#   'REMUS294_LHS_2.JPG',
#   'REMUS501_RHS_2.jpg',
#   'REMUS355_LHS_2.JPG',
#   'REMUS463_RHS_2.jpg',
#   'REMUS116_LHS_2.jpg',
#   'REMUS471_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_140.JPG',
#   'REMUS287_RHS_1.jpg',
#   'REMUS048_LHS_2.jpg',
#   'REMUS129_RHS_3.jpg',
#   'REMUS449_LHS_1.jpg',
#   'REMUS327_LHS_1.jpg',
#   'REMUS461_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_157.JPG',
#   '2007_071211NQ_WARMWATER_237.JPG',
#   'REMUS324_RHS_4.JPG',
#   'REMUS312_LHS_3.JPG',
#   'REMUS323_LHS_3.JPG',
#   'REMUS035_RHS_4.jpg',
#   'REMUS109_LHS_4.jpg',
#   'REMUS440_RHS_2.jpg',
#   'REMUS323_RHS_4.JPG',
#   'REMUS465_RHS_2.JPG',
#   'REMUS279_RHS_3.jpg',
#   'REMUS299_RHS_2.jpg',
#   'REMUS303_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_004.JPG',
#   'REMUS518_RHS_3.jpg',
#   'REMUS362_RHS_2.jpg',
#   'REMUS256_LHS_1.jpg',
#   'REMUS394_RHS_2.jpg',
#   'REMUS330_LHS_2.JPG',
#   'REMUS353_RHS_3.JPG',
#   'REMUS328_RHS_3.JPG',
#   'REMUS429_RHS_4.JPG',
#   'REMUS502_RHS_2.JPG',
#   'REMUS470_LHS_2.jpg',
#   'REMUS255_LHS_1.jpg',
#   'REMUS354_LHS_3.JPG',
#   '2007_071211NQ_WARMWATER_104.JPG',
#   'REMUS333_LHS_1.jpg',
#   'REMUS314_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_032.JPG',
#   '2007_071211NQ_WARMWATER_065.JPG',
#   'REMUS482_RHS_2.JPG',
#   'REMUS345_RHS_1.jpg',
#   'REMUS299_RHS_4.jpg',
#   'REMUS377_RHS_3.JPG',
#   'REMUS512_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_040.JPG',
#   'REMUS306_LHS_4.jpg',
#   'REMUS390_RHS_2.jpg',
#   'REMUS280_RHS_1.jpg',
#   'REMUS537_RHS_3.jpg',
#   'REMUS465_RHS_1.jpg',
#   'REMUS358_LHS_1.jpg',
#   'REMUS322_RHS_4.jpg',
#   'REMUS107_RHS_3.jpg',
#   'REMUS297_RHS_1.jpg',
#   'REMUS343_RHS_3.jpg',
#   'REMUS462_RHS_2.jpg',
#   'REMUS325_LHS_4.jpg',
#   'REMUS490_RHS_1.JPG',
#   'REMUS332_RHS_2.jpg',
#   'REMUS282_RHS_4.jpg',
#   'REMUS488_LHS_3.JPG',
#   'REMUS502_LHS_1.jpg',
#   'REMUS321_RHS_3.JPG',
#   'REMUS259_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_199.JPG',
#   'REMUS419_LHS_1.JPG',
#   'REMUS474_LHS_3.JPG',
#   '2013_130919_GAVIA_TASMANIA3.JPG',
#   '2007_071211NQ_WARMWATER_064.JPG',
#   'REMUS432_LHS_1.jpg',
#   'REMUS528_RHS_3.jpg',
#   'REMUS423_RHS_1.jpg',
#   'REMUS271_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_100.JPG',
#   'REMUS521_RHS_2.jpg',
#   'REMUS402_RHS_3.jpg',
#   'REMUS297_LHS_1.JPG',
#   'REMUS067_RHS_1.JPG',
#   'REMUS368_LHS_4.JPG',
#   'REMUS384_RHS_1.JPG',
#   'REMUS480_LHS_2.JPG',
#   'REMUS106_LHS_1.jpg',
#   'REMUS320_LHS_4.jpg',
#   'REMUS335_RHS_2.jpg',
#   'REMUS264_RHS_2.jpg',
#   'REMUS320_LHS_1.jpg',
#   'REMUS242_RHS_2.jpg',
#   'REMUS440_LHS_3.jpg',
#   'REMUS497_LHS_2.jpg',
#   'REMUS337_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_029.JPG',
#   'REMUS298_LHS_2.jpg',
#   'REMUS117_RHS_1.jpg',
#   'REMUS036_RHS_1.jpg',
#   'REMUS465_LHS_3.JPG',
#   'REMUS108_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_020.JPG',
#   '2007_071211NQ_WARMWATER_162.JPG',
#   'REMUS105_RHS_3.JPG',
#   'REMUS323_LHS_2.jpg',
#   'REMUS493_RHS_1.JPG',
#   'REMUS292_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_003.JPG',
#   'REMUS326_RHS_4.JPG',
#   'REMUS400_LHS_1.jpg',
#   'REMUS357_LHS_2.JPG',
#   'REMUS334_LHS_4.JPG',
#   '2007_071211NQ_WARMWATER_223.JPG',
#   'REMUS124_RHS_2.jpg',
#   'REMUS442_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_010.JPG',
#   'REMUS396_LHS_3.jpg',
#   'REMUS006_LHS_3.jpg',
#   'REMUS453_LHS_2.JPG',
#   'REMUS057_LHS_3.jpg',
#   '2007_071211NQ_WARMWATER_234.JPG',
#   'REMUS309_LHS_1.jpg',
#   'REMUS360_RHS_2.JPG',
#   'REMUS257_RHS_4.jpg',
#   'REMUS362_RHS_1.JPG',
#   'REMUS331_RHS_1.JPG',
#   'REMUS286_LHS_1.jpg',
#   'REMUS348_LHS_4.JPG',
#   'REMUS422_LHS_3.jpg',
#   'REMUS265_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_007.JPG',
#   'REMUS267_LHS_3.jpg',
#   'REMUS399_LHS_3.jpg',
#   'REMUS083_LHS_4.jpg',
#   'REMUS307_LHS_3.jpg',
#   'REMUS319_RHS_2.JPG',
#   '2007_071211NQ_WARMWATER_137.JPG',
#   'REMUS350_RHS_4.jpg',
#   'REMUS332_RHS_3.JPG',
#   'REMUS289_RHS_1.JPG',
#   'REMUS361_RHS_3.JPG',
#   '2007_071211NQ_WARMWATER_102.JPG',
#   'REMUS321_RHS_2.jpg',
#   'REMUS527_RHS_1.jpg',
#   'REMUS344_RHS_3.jpg',
#   'REMUS060_RHS_3.jpg',
#   'REMUS394_RHS_3.jpg',
#   'REMUS330_LHS_1.JPG',
#   '2007_071211NQ_WARMWATER_063.JPG',
#   'REMUS503_RHS_2.JPG',
#   'REMUS333_LHS_2.JPG',
#   'REMUS524_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_080.JPG',
#   'REMUS294_LHS_1.JPG',
#   'REMUS086_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_160.JPG',
#   'REMUS347_LHS_2.jpg',
#   'REMUS433_RHS_1.JPG',
#   'REMUS365_LHS_2.JPG',
#   'REMUS517_LHS_2.jpg',
#   'REMUS345_RHS_2.JPG',
#   'REMUS258_LHS_4.jpg',
#   'REMUS428_RHS_1.JPG',
#   'REMUS384_RHS_4.JPG',
#   'REMUS084_LHS_1.jpg',
#   'REMUS321_RHS_1.jpg',
#   'REMUS536_RHS_1.jpg',
#   'REMUS281_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_188.JPG',
#   'REMUS412_RHS_3.jpg',
#   'REMUS299_LHS_2.JPG',
#   'REMUS346_RHS_2.JPG',
#   '2007_071211NQ_WARMWATER_075.JPG',
#   'REMUS213_RHS_4.jpg',
#   'REMUS289_LHS_2.jpg',
#   '2007_071211NQ_WARMWATER_141.JPG',
#   'REMUS347_LHS_3.JPG',
#   'REMUS287_RHS_2.jpg',
#   'REMUS272_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_187.JPG',
#   'REMUS066_RHS_4.jpg',
#   'REMUS509_RHS_4.JPG',
#   'REMUS128_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_018.JPG',
#   'REMUS404_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_024.JPG',
#   'REMUS276_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_198.JPG',
#   'REMUS280_RHS_2.JPG',
#   'REMUS304_RHS_2.JPG',
#   'REMUS342_RHS_1.JPG',
#   '2007_071211NQ_WARMWATER_033.JPG',
#   'REMUS286_LHS_3.JPG',
#   'REMUS499_LHS_2.jpg',
#   'REMUS305_RHS_3.jpg',
#   'REMUS305_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_056.JPG',
#   'REMUS481_RHS_3.jpg',
#   'REMUS490_LHS_1.jpg',
#   'REMUS106_RHS_1.jpg',
#   'REMUS256_LHS_2.jpg',
#   'REMUS311_RHS_2.jpg',
#   'REMUS284_RHS_3.jpg',
#   'REMUS270_RHS_2.jpg',
#   'REMUS537_RHS_4.jpg',
#   'REMUS490_RHS_3.JPG',
#   'REMUS486_RHS_3.JPG',
#   'REMUS284_LHS_2.jpg',
#   'REMUS470_RHS_1.JPG',
#   'REMUS263_LHS_2.jpg',
#   'REMUS522_RHS_1.jpg',
#   'REMUS507_LHS_2.jpg',
#   'REMUS195_RHS_2.jpg',
#   'REMUS325_LHS_2.JPG',
#   'REMUS504_RHS_3.jpg',
#   '2007_071211NQ_WARMWATER_114.JPG',
#   'REMUS262_RHS_4.jpg',
#   'REMUS431_LHS_4.JPG',
#   'REMUS282_RHS_2.jpg',
#   'REMUS351_RHS_2.jpg',
#   'REMUS152_LHS_2.jpg',
#   'REMUS432_RHS_2.JPG',
#   'REMUS275_LHS_3.jpg',
#   'REMUS361_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_165.JPG',
#   'REMUS259_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_049.JPG',
#   'REMUS334_RHS_3.JPG',
#   'REMUS335_LHS_2.jpg',
#   'REMUS523_RHS_2.jpg',
#   'REMUS252_LHS_1.jpg',
#   '2007_071211NQ_WARMWATER_030.JPG',
#   'REMUS266_RHS_3.jpg',
#   'REMUS394_RHS_1.jpg',
#   'REMUS318_RHS_3.jpg',
#   'REMUS290_RHS_4.JPG',
#   '2007_071211NQ_WARMWATER_161.JPG',
#   'REMUS487_LHS_4.JPG',
#   'REMUS273_RHS_4.jpg',
#   '2007_071211NQ_WARMWATER_039.JPG',
#   'REMUS072_RHS_2.jpg',
#   'REMUS255_LHS_2.jpg',
#   'REMUS301_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_123.JPG',
#   'REMUS316_RHS_2.jpg',
#   'REMUS523_RHS_4.jpg',
#   'REMUS299_LHS_4.jpg',
#   'REMUS340_RHS_2.jpg',
#   '2007_071211NQ_WARMWATER_000.JPG',
#   'REMUS264_LHS_1.jpg',
#   'REMUS430_RHS_3.jpg',
#   'REMUS271_RHS_3.jpg',
#   'REMUS100_LHS_4.jpg',
#   'REMUS288_RHS_3.JPG',
#   'REMUS315_LHS_4.jpg',
#   'REMUS508_LHS_4.jpg',
#   'REMUS312_LHS_1.JPG',
#   'REMUS348_LHS_3.jpg',
#   'REMUS065_RHS_1.jpg',
#   'REMUS266_RHS_2.jpg',
#   'REMUS489_RHS_3.JPG',
#   'REMUS282_LHS_4.jpg',
#   'REMUS529_RHS_3.jpg',
#   'REMUS284_LHS_1.JPG',
#   'REMUS515_LHS_3.jpg',
#   'REMUS415_LHS_2.jpg',
#   'REMUS315_RHS_1.JPG',
#   'REMUS458_LHS_2.jpg',
#   'REMUS255_LHS_4.jpg',
#   'REMUS022_RHS_2.jpg',
#   'REMUS467_RHS_4.jpg',
#   'REMUS282_LHS_2.JPG',
#   'REMUS390_LHS_1.JPG',
#   'REMUS358_RHS_1.jpg',
#   'REMUS373_LHS_4.jpg',
#   '2007_071211NQ_WARMWATER_071.JPG',
#   'REMUS290_LHS_1.JPG',
#   'REMUS437_LHS_3.jpg',
# ...
#   'REMUS112_RHS_4.JPG',
#   'REMUS130_RHS_4.jpg',
#   'REMUS470_LHS_1.jpg',
#   'REMUS230_RHS_3.jpg',
#   'REMUS207_LHS_2.JPG',
#   'REMUS270_LHS_2.jpg',
#   'REMUS015_LHS_4.jpg',
#   'REMUS137_LHS_1.JPG',
#   'REMUS487_RHS_3.jpg',
#   'REMUS253_RHS_4.jpg',
#   'REMUS511_LHS_1.jpg',
#   'REMUS269_RHS_4.jpg',
#   'REMUS372_LHS_3.jpg',
#   'REMUS281_RHS_3.JPG',
#   'REMUS009_LHS_2.jpg',
#   'REMUS177_RHS_1.JPG',
#   'REMUS124_RHS_4.jpg',
#   'REMUS135_LHS_1.JPG',
#   'REMUS512_LHS_2.jpg',
#   'REMUS383_RHS_4.jpg',
#   'REMUS101_RHS_4.jpg',
#   'REMUS085_LHS_1.jpg',
#   'REMUS279_LHS_1.JPG',
#   'REMUS276_LHS_3.jpg',
#   'REMUS115_LHS_2.JPG',
#   'REMUS141_LHS_2.jpg',
#   'REMUS142_RHS_3.jpg',
#   'REMUS279_RHS_1.JPG',
#   'REMUS013_RHS_2.jpg',
#   'REMUS127_RHS_3.jpg',
#   'REMUS467_LHS_2.jpg',
#   'REMUS131_RHS_3.jpg',
#   'REMUS466_RHS_4.jpg',
#   'REMUS006_LHS_1.jpg',
#   'REMUS112_LHS_2.JPG',
#   'REMUS179_RHS_3.jpg',
#   'REMUS152_RHS_1.JPG',
#   'REMUS154_LHS_3.jpg',
#   'REMUS018_RHS_2.jpg',
#   'REMUS151_LHS_1.jpg',
#   'REMUS047_LHS_1.jpg',
#   'REMUS370_LHS_2.jpg',
#   'REMUS013_LHS_2.jpg',
#   'REMUS191_LHS_2.jpg',
#   'REMUS218_LHS_3.jpg',
#   'REMUS162_LHS_4.JPG',
#   'REMUS443_RHS_2.jpg',
#   'REMUS204_LHS_1.jpg',
#   'REMUS271_LHS_2.jpg',
#   'REMUS090_RHS_4.jpg',
#   'REMUS102_RHS_1.jpg',
#   'REMUS264_LHS_2.jpg',
#   'REMUS374_RHS_3.jpg',
#   'REMUS106_RHS_2.jpg',
#   'REMUS435_LHS_2.jpg',
#   'REMUS475_RHS_1.jpg',
#   'REMUS017_RHS_4.jpg',
#   'REMUS141_RHS_1.jpg',
#   'REMUS001_LHS_2.jpg',
#   'REMUS021_LHS_3.jpg',
#   'REMUS185_LHS_1.JPG',
#   'REMUS186_RHS_1.jpg',
#   'REMUS398_RHS_1.jpg',
#   'REMUS029_LHS_3.jpg',
#   'REMUS173_RHS_4.jpg',
#   'REMUS233_RHS_2.jpg',
#   'REMUS442_LHS_3.jpg',
#   'REMUS154_LHS_2.jpg',
#   'REMUS452_LHS_2.jpg',
#   'REMUS515_RHS_2.jpg',
#   'REMUS271_LHS_4.jpg',
#   'REMUS014_RHS_3.jpg',
#   'REMUS014_LHS_2.jpg',
#   'REMUS079_RHS_3.jpg',
#   'REMUS078_LHS_1.jpg',
#   'REMUS056_LHS_3.jpg',
#   'REMUS280_RHS_3.JPG',
#   'REMUS160_RHS_2.JPG',
#   'REMUS183_LHS_2.jpg',
#   'REMUS046_RHS_4.jpg',
#   'REMUS264_LHS_4.jpg',
#   'REMUS060_LHS_4.jpg',
#   'REMUS107_RHS_1.jpg',
#   'REMUS443_LHS_2.jpg',
#   'REMUS187_LHS_3.jpg',
#   'REMUS273_LHS_3.jpg',
#   'REMUS158_RHS_1.jpg',
#   'REMUS170_LHS_1.JPG',
#   'REMUS211_RHS_4.jpg',
#   'REMUS452_RHS_2.jpg',
#   'REMUS193_LHS_2.JPG',
#   'REMUS102_LHS_2.jpg',
#   'REMUS034_LHS_2.jpg',
#   'REMUS380_RHS_2.jpg',
#   'REMUS134_LHS_3.jpg',
#   'REMUS099_RHS_2.JPG',
#   'REMUS074_RHS_4.jpg',
#   'REMUS231_LHS_1.jpg',
#   'REMUS186_LHS_1.jpg',
#   'REMUS253_LHS_4.jpg',
#   'REMUS125_RHS_4.JPG',
#   'REMUS059_RHS_4.jpg',
#   'REMUS241_LHS_4.JPG',
#   'REMUS091_LHS_4.jpg',
#   'REMUS123_LHS_3.jpg',
#   'REMUS211_LHS_2.jpg',
#   'REMUS187_RHS_4.jpg',
#   'REMUS151_RHS_3.JPG',
#   'REMUS146_LHS_4.jpg',
#   'REMUS048_RHS_2.jpg',
#   'REMUS131_RHS_1.jpg',
#   'REMUS054_LHS_3.jpg',
#   'REMUS450_LHS_4.jpg',
#   'REMUS406_LHS_1.jpg',
#   'REMUS135_LHS_3.JPG',
#   'REMUS403_LHS_3.jpg',
#   'REMUS156_RHS_3.jpg',
#   'REMUS024_LHS_4.jpg',
#   'REMUS242_RHS_4.JPG',
#   'REMUS051_RHS_4.jpg',
#   'REMUS195_LHS_1.jpg',
#   'REMUS036_LHS_4.jpg',
#   'REMUS142_LHS_2.jpg',
#   'REMUS106_RHS_1.JPG',
#   'REMUS080_LHS_1.jpg',
#   'REMUS107_LHS_1.jpg',
#   'REMUS370_RHS_4.jpg',
#   'REMUS403_RHS_3.jpg',
#   'REMUS273_LHS_1.jpg',
#   'REMUS403_LHS_4.jpg',
#   'REMUS366_RHS_4.jpg',
#   'REMUS379_RHS_3.jpg',
#   'REMUS284_RHS_4.JPG',
#   'REMUS158_RHS_4.jpg',
#   'REMUS092_RHS_2.jpg',
#   'REMUS035_LHS_3.jpg',
#   'REMUS073_RHS_1.jpg',
#   'REMUS368_LHS_1.jpg',
#   'REMUS080_LHS_3.jpg',
#   'REMUS226_LHS_2.jpg',
#   'REMUS252_LHS_2.JPG',
#   'REMUS092_LHS_2.jpg',
#   'REMUS165_RHS_1.jpg',
#   'REMUS398_LHS_1.jpg',
#   'REMUS455_LHS_4.jpg',
#   'REMUS134_RHS_1.jpg',
#   'REMUS477_LHS_2.jpg',
#   'REMUS227_LHS_2.jpg',
#   'REMUS392_RHS_1.jpg',
#   'REMUS200_LHS_2.jpg',
#   'REMUS205_RHS_1.jpg',
#   'REMUS364_RHS_3.jpg',
#   'REMUS049_LHS_1.jpg',
#   'REMUS298_LHS_1.JPG',
#   'REMUS102_RHS_4.jpg',
#   'REMUS443_LHS_1.jpg',
#   'REMUS190_LHS_1.jpg',
#   'REMUS164_RHS_1.jpg',
#   'REMUS264_RHS_1.JPG',
#   'REMUS094_RHS_4.jpg',
#   'REMUS088_LHS_1.jpg',
#   'REMUS263_RHS_2.jpg',
#   'REMUS465_LHS_1.jpg',
#   'REMUS162_RHS_1.jpg',
#   'REMUS019_RHS_1.jpg',
#   'REMUS487_RHS_1.jpg',
#   'REMUS506_LHS_3.jpg',
#   'REMUS421_LHS_1.jpg',
#   'REMUS129_LHS_3.jpg',
#   'REMUS012_RHS_2.jpg',
#   'REMUS092_LHS_1.jpg',
#   'REMUS200_RHS_3.jpg',
#   'REMUS516_LHS_3.jpg',
#   'REMUS235_LHS_4.JPG',
#   'REMUS467_LHS_1.jpg',
#   'REMUS428_LHS_4.jpg',
#   'REMUS006_LHS_2.jpg',
#   'REMUS462_LHS_4.jpg',
#   'REMUS193_RHS_4.jpg',
#   'REMUS055_RHS_1.jpg',
#   'REMUS217_RHS_3.jpg',
#   'REMUS244_LHS_3.jpg',
#   'REMUS138_LHS_3.jpg',
#   'REMUS199_LHS_3.JPG',
#   'REMUS182_LHS_4.jpg',
#   'REMUS196_RHS_4.JPG',
#   'REMUS024_RHS_2.jpg',
#   'REMUS389_LHS_3.jpg',
#   'REMUS168_LHS_2.JPG',
#   'REMUS274_RHS_2.jpg',
#   'REMUS250_RHS_4.jpg',
#   'REMUS116_LHS_2.jpg',
#   'REMUS171_RHS_2.jpg',
#   'REMUS142_RHS_1.JPG',
#   'REMUS174_LHS_3.jpg',
#   'REMUS013_RHS_4.jpg',
#   'REMUS243_RHS_2.JPG',
#   'REMUS129_RHS_3.jpg',
#   'REMUS155_RHS_1.jpg',
#   'REMUS005_RHS_3.jpg',
#   'REMUS122_LHS_3.jpg',
#   'REMUS401_LHS_3.jpg',
#   'REMUS016_LHS_2.jpg',
#   'REMUS132_RHS_3.JPG',
#   'REMUS195_LHS_4.JPG',
#   'REMUS035_RHS_4.jpg',
#   'REMUS246_RHS_1.jpg',
#   'REMUS109_LHS_4.jpg',
#   'REMUS097_RHS_3.jpg',
#   'REMUS034_LHS_4.jpg',
#   'REMUS197_RHS_1.jpg',
#   'REMUS484_LHS_2.jpg',
#   'REMUS437_LHS_4.jpg',
#   'REMUS235_RHS_4.jpg',
#   'REMUS203_RHS_3.jpg',
#   'REMUS418_RHS_1.jpg',
#   'REMUS256_LHS_1.jpg',
#   'REMUS455_RHS_2.jpg',
#   'REMUS247_LHS_1.jpg',
#   'REMUS159_LHS_1.JPG',
#   'REMUS029_RHS_4.jpg',
#   'REMUS238_RHS_3.JPG',
#   'REMUS082_RHS_1.jpg',
#   'REMUS087_RHS_3.jpg',
#   'REMUS116_RHS_1.jpg',
#   'REMUS112_LHS_4.JPG',
#   'REMUS166_LHS_2.JPG',
#   'REMUS021_LHS_2.jpg',
#   'REMUS197_RHS_3.JPG',
#   'REMUS139_RHS_3.jpg',
#   'REMUS384_LHS_4.jpg',
#   'REMUS317_RHS_1.JPG',
#   'REMUS008_RHS_2.jpg',
#   'REMUS255_LHS_1.jpg',
#   'REMUS152_RHS_4.jpg',
#   'REMUS068_LHS_3.jpg',
#   'REMUS247_RHS_1.jpg',
#   'REMUS036_LHS_1.jpg',
#   'REMUS057_RHS_3.jpg',
#   'REMUS251_LHS_3.jpg',
#   'REMUS045_LHS_2.jpg',
#   'REMUS054_RHS_3.jpg',
#   'REMUS078_LHS_2.jpg',
#   'REMUS010_RHS_1.jpg',
#   'REMUS037_LHS_4.jpg',
#   'REMUS076_LHS_1.jpg',
#   'REMUS475_LHS_3.jpg',
#   'REMUS240_LHS_2.JPG',
#   'REMUS248_RHS_1.jpg',
#   'REMUS150_LHS_2.jpg',
#   'REMUS387_LHS_3.jpg',
#   'REMUS451_LHS_2.jpg',
#   'REMUS164_LHS_4.JPG',
#   'REMUS243_LHS_2.JPG',
#   'REMUS231_RHS_3.jpg',
#   'REMUS420_RHS_2.jpg',
#   'REMUS134_LHS_2.jpg',
#   'REMUS010_LHS_1.jpg',
#   'REMUS099_LHS_2.jpg',
#   'REMUS191_RHS_2.jpg',
#   'REMUS149_LHS_2.JPG',
#   'REMUS221_RHS_3.JPG',
#   'REMUS214_RHS_4.jpg',
#   'REMUS036_RHS_4.jpg',
#   'REMUS049_RHS_4.jpg',
#   'REMUS079_LHS_2.jpg',
#   'REMUS001_LHS_4.jpg',
#   'REMUS026_LHS_1.jpg',
#   'REMUS246_RHS_2.jpg',
#   'REMUS272_RHS_3.JPG',
#   'REMUS023_LHS_4.jpg',
#   'REMUS085_RHS_2.jpg',
#   'REMUS120_LHS_4.jpg',
#   'REMUS405_LHS_1.jpg',
#   'REMUS047_RHS_1.jpg',
#   'REMUS022_LHS_3.jpg',
#   'REMUS186_RHS_4.jpg',
#   'REMUS169_LHS_2.jpg',
#   'REMUS213_RHS_2.jpg',
#   'REMUS013_LHS_4.jpg',
#   'REMUS111_RHS_2.jpg',
#   'REMUS076_RHS_4.jpg',
#   'REMUS132_LHS_2.JPG',
#   'REMUS219_LHS_4.jpg',
#   'REMUS031_RHS_1.jpg',
#   'REMUS076_LHS_2.jpg',
#   'REMUS042_LHS_2.jpg',
#   'REMUS204_RHS_2.jpg',
#   'REMUS106_LHS_1.jpg',
#   ...],
#  ['REMUS004_LHS_3.jpg',
#   'REMUS416_LHS_4.jpg',
#   'REMUS080_RHS_3.jpg',
#   'REMUS077_RHS_2.jpg',
#   'REMUS118_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI08.JPG',
#   'REMUS088_LHS_3.jpg',
#   'REMUS062_RHS_4.jpg',
#   'REMUS065_LHS_4.jpg',
#   'REMUS117_LHS_2.jpg',
#   'REMUS005_LHS_3.jpg',
#   'REMUS004_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI23.JPG',
#   '2011_110328SP_WESTERNPACI28.JPG',
#   'REMUS117_RHS_2.jpg',
#   'REMUS016_RHS_2.jpg',
#   'REMUS114_RHS_2.jpg',
#   'REMUS050_LHS_3.jpg',
#   'REMUS014_RHS_2.jpg',
#   'REMUS062_LHS_4.jpg',
#   'R09.JPG',
#   '2011_110328SP_WESTERNPACI19.JPG',
#   'REMUS042_LHS_4.jpg',
#   'REMUS184_LHS_4.jpg',
#   'REMUS121_LHS_3.jpg',
#   'REMUS091_LHS_2.jpg',
#   'R04.JPG',
#   'REMUS210_RHS_2.jpg',
#   'REMUS131_LHS_2.jpg',
#   'REMUS206_RHS_4.jpg',
#   'REMUS215_LHS_2.jpg',
#   'REMUS184_RHS_1.jpg',
#   'REMUS103_RHS_1.jpg',
#   'REMUS083_LHS_1.jpg',
#   'REMUS065_RHS_3.jpg',
#   'REMUS056_RHS_4.jpg',
#   'REMUS108_LHS_1.jpg',
#   'REMUS076_LHS_4.jpg',
#   'REMUS068_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI04.JPG',
#   '2011_110328SP_WESTERNPACI27.JPG',
#   'REMUS097_LHS_2.jpg',
#   'REMUS134_RHS_3.jpg',
#   'REMUS147_LHS_2.jpg',
#   'REMUS106_LHS_3.jpg',
#   'REMUS118_LHS_3.jpg',
#   'REMUS100_LHS_1.jpg',
#   'REMUS003_LHS_4.jpg',
#   'REMUS105_RHS_4.JPG',
#   'REMUS076_LHS_3.jpg',
#   'REMUS064_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI05.JPG',
#   'REMUS096_RHS_4.jpg',
#   'REMUS147_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI20.JPG',
#   'REMUS089_LHS_4.jpg',
#   'REMUS106_RHS_3.jpg',
#   'REMUS079_LHS_4.jpg',
#   'REMUS104_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI17.JPG',
#   'REMUS067_LHS_2.jpg',
#   'R03.JPG',
#   'REMUS066_LHS_1.jpg',
#   'REMUS377_RHS_4.jpg',
#   'REMUS210_RHS_3.jpg',
#   'REMUS049_RHS_1.jpg',
#   'REMUS510_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI24.JPG',
#   'REMUS073_LHS_1.jpg',
#   'REMUS054_RHS_2.jpg',
#   'REMUS102_RHS_1.jpg',
#   '2011_110328SP_WESTERNPACI18.JPG',
#   'REMUS014_RHS_3.jpg',
#   'REMUS046_RHS_4.jpg',
#   'REMUS060_LHS_4.jpg',
#   'REMUS130_LHS_1.jpg',
#   'REMUS074_RHS_4.jpg',
#   'REMUS448_RHS_4.jpg',
#   'REMUS118_LHS_2.jpg',
#   'REMUS080_LHS_1.jpg',
#   'REMUS073_RHS_1.jpg',
#   'REMUS083_RHS_3.jpg',
#   'REMUS080_LHS_3.jpg',
#   'REMUS200_LHS_2.jpg',
#   'REMUS109_LHS_4.jpg',
#   'R08.JPG',
#   'REMUS124_LHS_1.jpg',
#   'REMUS108_RHS_1.jpg',
#   'REMUS515_LHS_2.jpg',
#   'REMUS080_LHS_2.jpg',
#   'REMUS063_LHS_1.jpg',
#   'REMUS042_LHS_2.jpg',
#   'REMUS106_LHS_1.jpg',
#   'REMUS450_LHS_2.jpg',
#   'REMUS117_RHS_1.jpg',
#   'REMUS070_RHS_1.jpg',
#   'REMUS084_LHS_4.jpg',
#   'REMUS103_RHS_4.JPG',
#   'REMUS070_LHS_2.jpg',
#   'REMUS061_RHS_3.jpg',
#   'REMUS005_RHS_4.jpg',
#   'REMUS472_LHS_2.jpg',
#   'REMUS113_RHS_4.jpg',
#   'REMUS082_LHS_4.jpg',
#   'REMUS004_RHS_1.jpg',
#   'REMUS447_LHS_3.jpg',
#   'REMUS146_LHS_1.jpg',
#   'REMUS087_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI16.JPG',
#   'REMUS131_LHS_3.jpg',
#   'REMUS083_RHS_4.jpg',
#   'REMUS081_RHS_2.jpg',
#   '2011_110328SP_WESTERNPACI00.JPG',
#   'REMUS374_RHS_2.jpg',
#   'REMUS042_LHS_3.jpg',
#   'REMUS018_RHS_3.jpg',
#   'REMUS095_RHS_1.jpg',
#   'REMUS043_LHS_4.jpg',
#   'REMUS089_RHS_4.jpg',
#   'REMUS075_LHS_2.jpg',
#   'REMUS055_RHS_2.jpg',
#   'REMUS215_LHS_4.jpg',
#   'R10.JPG',
#   'REMUS097_LHS_1.jpg',
#   'REMUS207_LHS_1.jpg',
#   'REMUS080_LHS_4.jpg',
#   'REMUS062_RHS_3.jpg',
#   'REMUS352_RHS_2.jpg',
#   '2011_110328SP_WESTERNPACI14.JPG',
#   'REMUS118_RHS_3.jpg',
#   'REMUS062_RHS_2.jpg',
#   'REMUS119_RHS_4.jpg',
#   'REMUS062_LHS_2.jpg',
#   'REMUS271_RHS_1.jpg',
#   'REMUS054_LHS_1.jpg',
#   'REMUS009_LHS_1.jpg',
#   'REMUS209_RHS_1.jpg',
#   'REMUS041_LHS_1.jpg',
#   'REMUS111_LHS_1.jpg',
#   'REMUS459_RHS_4.jpg',
#   'REMUS041_LHS_2.jpg',
#   'REMUS040_RHS_2.jpg',
#   'REMUS109_RHS_4.jpg',
#   'REMUS214_LHS_1.jpg',
#   'REMUS075_LHS_3.jpg',
#   'REMUS210_RHS_1.jpg',
#   'REMUS079_LHS_1.jpg',
#   'REMUS087_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI06.JPG',
#   'REMUS004_RHS_3.jpg',
#   'REMUS132_RHS_3.jpg',
#   'REMUS132_RHS_2.jpg',
#   'REMUS271_LHS_1.jpg',
#   'REMUS088_RHS_1.jpg',
#   'R01.JPG',
#   'REMUS004_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI21.JPG',
#   'REMUS072_LHS_2.jpg',
#   'REMUS119_LHS_2.jpg',
#   'REMUS210_RHS_4.jpg',
#   'REMUS080_RHS_1.jpg',
#   '2011_110328SP_WESTERNPACI03.JPG',
#   'REMUS075_RHS_1.jpg',
#   'REMUS080_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI10.JPG',
#   'REMUS081_LHS_1.jpg',
#   'REMUS185_LHS_4.jpg',
#   'REMUS014_RHS_1.jpg',
#   'REMUS145_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI12.JPG',
#   'R02.JPG',
#   'REMUS102_LHS_1.jpg',
#   'REMUS132_LHS_2.jpg',
#   'REMUS087_RHS_2.jpg',
#   'REMUS209_LHS_2.jpg',
#   'REMUS041_RHS_1.jpg',
#   'REMUS397_LHS_2.jpg',
#   'REMUS042_RHS_2.jpg',
#   'REMUS070_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI13.JPG',
#   'REMUS210_LHS_2.jpg',
#   'REMUS004_LHS_3.jpg',
#   'REMUS416_LHS_4.jpg',
#   'REMUS080_RHS_3.jpg',
#   'REMUS077_RHS_2.jpg',
#   'REMUS118_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI08.JPG',
#   'REMUS088_LHS_3.jpg',
#   'REMUS062_RHS_4.jpg',
#   'REMUS065_LHS_4.jpg',
#   'REMUS117_LHS_2.jpg',
#   'REMUS005_LHS_3.jpg',
#   'REMUS004_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI23.JPG',
#   '2011_110328SP_WESTERNPACI28.JPG',
#   'REMUS117_RHS_2.jpg',
#   'REMUS016_RHS_2.jpg',
#   'REMUS114_RHS_2.jpg',
#   'REMUS050_LHS_3.jpg',
#   'REMUS014_RHS_2.jpg',
#   'REMUS062_LHS_4.jpg',
#   'R09.JPG',
#   '2011_110328SP_WESTERNPACI19.JPG',
#   'REMUS042_LHS_4.jpg',
#   'REMUS184_LHS_4.jpg',
#   'REMUS121_LHS_3.jpg',
#   'REMUS091_LHS_2.jpg',
#   'R04.JPG',
#   'REMUS210_RHS_2.jpg',
#   'REMUS131_LHS_2.jpg',
#   'REMUS206_RHS_4.jpg',
#   'REMUS215_LHS_2.jpg',
#   'REMUS184_RHS_1.jpg',
#   'REMUS103_RHS_1.jpg',
#   'REMUS083_LHS_1.jpg',
#   'REMUS065_RHS_3.jpg',
#   'REMUS056_RHS_4.jpg',
#   'REMUS108_LHS_1.jpg',
#   'REMUS076_LHS_4.jpg',
#   'REMUS068_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI04.JPG',
#   '2011_110328SP_WESTERNPACI27.JPG',
#   'REMUS097_LHS_2.jpg',
#   'REMUS134_RHS_3.jpg',
#   'REMUS147_LHS_2.jpg',
#   'REMUS106_LHS_3.jpg',
#   'REMUS118_LHS_3.jpg',
#   'REMUS100_LHS_1.jpg',
#   'REMUS003_LHS_4.jpg',
#   'REMUS105_RHS_4.JPG',
#   'REMUS076_LHS_3.jpg',
#   'REMUS064_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI05.JPG',
#   'REMUS096_RHS_4.jpg',
#   'REMUS147_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI20.JPG',
#   'REMUS089_LHS_4.jpg',
#   'REMUS106_RHS_3.jpg',
#   'REMUS079_LHS_4.jpg',
#   'REMUS104_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI17.JPG',
#   'REMUS067_LHS_2.jpg',
#   'R03.JPG',
#   'REMUS066_LHS_1.jpg',
#   'REMUS377_RHS_4.jpg',
#   'REMUS210_RHS_3.jpg',
#   'REMUS049_RHS_1.jpg',
#   'REMUS510_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI24.JPG',
#   'REMUS073_LHS_1.jpg',
#   'REMUS054_RHS_2.jpg',
#   'REMUS102_RHS_1.jpg',
#   '2011_110328SP_WESTERNPACI18.JPG',
#   'REMUS014_RHS_3.jpg',
#   'REMUS046_RHS_4.jpg',
#   'REMUS060_LHS_4.jpg',
#   'REMUS130_LHS_1.jpg',
#   'REMUS074_RHS_4.jpg',
#   'REMUS448_RHS_4.jpg',
#   'REMUS118_LHS_2.jpg',
#   'REMUS080_LHS_1.jpg',
#   'REMUS073_RHS_1.jpg',
#   'REMUS083_RHS_3.jpg',
#   'REMUS080_LHS_3.jpg',
#   'REMUS200_LHS_2.jpg',
#   'REMUS109_LHS_4.jpg',
#   'R08.JPG',
#   'REMUS124_LHS_1.jpg',
#   'REMUS108_RHS_1.jpg',
#   'REMUS515_LHS_2.jpg',
#   'REMUS080_LHS_2.jpg',
#   'REMUS063_LHS_1.jpg',
#   'REMUS042_LHS_2.jpg',
#   'REMUS106_LHS_1.jpg',
#   'REMUS450_LHS_2.jpg',
#   'REMUS117_RHS_1.jpg',
#   'REMUS070_RHS_1.jpg',
#   'REMUS084_LHS_4.jpg',
#   'REMUS103_RHS_4.JPG',
#   'REMUS070_LHS_2.jpg',
#   'REMUS061_RHS_3.jpg',
#   'REMUS005_RHS_4.jpg',
#   'REMUS472_LHS_2.jpg',
#   'REMUS113_RHS_4.jpg',
#   'REMUS082_LHS_4.jpg',
#   'REMUS004_RHS_1.jpg',
#   'REMUS447_LHS_3.jpg',
#   'REMUS146_LHS_1.jpg',
#   'REMUS087_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI16.JPG',
#   'REMUS131_LHS_3.jpg',
#   'REMUS083_RHS_4.jpg',
#   'REMUS081_RHS_2.jpg',
#   '2011_110328SP_WESTERNPACI00.JPG',
#   'REMUS374_RHS_2.jpg',
#   'REMUS042_LHS_3.jpg',
#   'REMUS018_RHS_3.jpg',
#   'REMUS095_RHS_1.jpg',
#   'REMUS043_LHS_4.jpg',
#   'REMUS089_RHS_4.jpg',
#   'REMUS075_LHS_2.jpg',
#   'REMUS055_RHS_2.jpg',
#   'REMUS215_LHS_4.jpg',
#   'R10.JPG',
#   'REMUS097_LHS_1.jpg',
#   'REMUS207_LHS_1.jpg',
#   'REMUS080_LHS_4.jpg',
#   'REMUS062_RHS_3.jpg',
#   'REMUS352_RHS_2.jpg',
#   '2011_110328SP_WESTERNPACI14.JPG',
#   'REMUS118_RHS_3.jpg',
#   'REMUS062_RHS_2.jpg',
#   'REMUS119_RHS_4.jpg',
#   'REMUS062_LHS_2.jpg',
#   'REMUS271_RHS_1.jpg',
#   'REMUS054_LHS_1.jpg',
#   'REMUS009_LHS_1.jpg',
#   'REMUS209_RHS_1.jpg',
#   'REMUS041_LHS_1.jpg',
#   'REMUS111_LHS_1.jpg',
#   'REMUS459_RHS_4.jpg',
#   'REMUS041_LHS_2.jpg',
#   'REMUS040_RHS_2.jpg',
#   'REMUS109_RHS_4.jpg',
#   'REMUS214_LHS_1.jpg',
#   'REMUS075_LHS_3.jpg',
#   'REMUS210_RHS_1.jpg',
#   'REMUS079_LHS_1.jpg',
#   'REMUS087_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI06.JPG',
#   'REMUS004_RHS_3.jpg',
#   'REMUS132_RHS_3.jpg',
#   'REMUS132_RHS_2.jpg',
#   'REMUS271_LHS_1.jpg',
#   'REMUS088_RHS_1.jpg',
#   'R01.JPG',
#   'REMUS004_LHS_2.jpg',
#   '2011_110328SP_WESTERNPACI21.JPG',
#   'REMUS072_LHS_2.jpg',
#   'REMUS119_LHS_2.jpg',
#   'REMUS210_RHS_4.jpg',
#   'REMUS080_RHS_1.jpg',
#   '2011_110328SP_WESTERNPACI03.JPG',
#   'REMUS075_RHS_1.jpg',
#   'REMUS080_RHS_4.jpg',
#   '2011_110328SP_WESTERNPACI10.JPG',
#   'REMUS081_LHS_1.jpg',
#   'REMUS185_LHS_4.jpg',
#   'REMUS014_RHS_1.jpg',
#   'REMUS145_LHS_4.jpg',
#   '2011_110328SP_WESTERNPACI12.JPG',
#   'R02.JPG',
#   'REMUS102_LHS_1.jpg',
#   'REMUS132_LHS_2.jpg',
#   'REMUS087_RHS_2.jpg',
#   'REMUS209_LHS_2.jpg',
#   'REMUS041_RHS_1.jpg',
#   'REMUS397_LHS_2.jpg',
#   'REMUS042_RHS_2.jpg',
#   'REMUS070_LHS_1.jpg',
#   '2011_110328SP_WESTERNPACI13.JPG',
#   'REMUS210_LHS_2.jpg']]
